# %% [markdown]
# # Introduction
# Practice flattening JSON files loaded from downloaded files and requesting data from Yelp using the API connection. We will also query data from PostgreSQL DVDrental database using psycopg2 and SQLAlchemy.

# %% [markdown]
# ## Imports
# Import libraries and write settings here.

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Options for pandas
import requests
from sqlalchemy import *
import psycopg2
from pandas.io.json import json_normalize

# %% [markdown]
# # Load data directly from JSON files

# %% [markdown]
# ## Yelp data

# %%
# path
path_yelp = 'G:/Mi unidad/GITHUB/data_science_projects/use_SQL_json_files/yelp_academic_dataset_business.json'

# read json files directly with pd.read_json
yelp_json = pd.read_json(path_yelp, orient='records', lines=True)
display(yelp_json.head())
# Out:
#                    business_id                     name               address  \
# 0       6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom          921 Pearl St
# 1       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX   7000 NE Airport Way
# 2       bvN78flM8NLprQ1a1y5dRg           The Reclaimory    4720 Hawthorne Ave
# 3       oaepsyvc0J17qwi8cfrOWg              Great Clips    2566 Enterprise Rd
# 4       PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus   1046 Memorial Dr SE
# ...                        ...                      ...                   ...
# 160580  D2mHoIDXx9N8mS1pGoKV9Q       Eleven Oaks Realty
# 160581  bQX-kwVTyZgcdZGEPzce6Q             Webb's Honey    21777 State Rd 520
# 160582  wvFZ06nmPmQ2-IVoPqVYLA    Painting with a Twist  2164 S Chickasaw Trl
# 160583  GB75wPibj3IjNauaoCxyGA              Havana Cafe        910 NW 14th St
# 160584  ngmLL5Y5OT-bYHKU0kKrYA              Zora Grille   1370 E Altamonte Dr
#
#                      city state postal_code   latitude   longitude  stars  \
# 0                 Boulder    CO       80302  40.017544 -105.283348    4.0
# 1                Portland    OR       97218  45.588906 -122.593331    4.0
# 2                Portland    OR       97214  45.511907 -122.613693    4.5
# 3             Orange City    FL       32763  28.914482  -81.295979    3.0
# 4                 Atlanta    GA       30316  33.747027  -84.353424    4.0
# ...                   ...   ...         ...        ...         ...    ...
# 160580             Austin    TX       78701  30.272921  -97.744386    4.0
# 160581            Orlando    FL       32833  28.499836  -81.047478    4.5
# 160582            Orlando    FL       32825  28.511615  -81.270020    5.0
# 160583           Portland    OR       97209  45.529647 -122.685153    4.0
# 160584  Altamonte Springs    FL       32701  28.663047  -81.346728    4.5
#
#         review_count  is_open  \
# 0                 86        1
# 1                126        1
# 2                 13        1
# 3                  8        1
# 4                 14        1
# ...              ...      ...
# 160580             8        1
# 160581            18        1
# 160582             8        0
# 160583            10        1
# 160584            82        0
#
#                                                attributes  \
# 0       {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2       {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3       {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 4       {'GoodForKids': 'False', 'BusinessParking': '{...
# ...                                                   ...
# 160580                                               None
# 160581  {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# 160582  {'DogsAllowed': 'False', 'ByAppointmentOnly': ...
# 160583  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 160584  {'RestaurantsReservations': 'True', 'OutdoorSe...
#
#                                                categories  \
# 0       Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2       Antiques, Fashion, Used, Vintage & Consignment...
# 3                              Beauty & Spas, Hair Salons
# 4       Gyms, Active Life, Interval Training Gyms, Fit...
# ...                                                   ...
# 160580  Real Estate, Real Estate Services, Home Servic...
# 160581      Health Markets, Food, Specialty Food, Grocery
# 160582  Arts & Entertainment, Paint & Sip, Art Classes...
# 160583              Cuban, Sandwiches, Restaurants, Cafes
# 160584  Restaurants, Middle Eastern, Mediterranean, Pe...
#
#                                                     hours
# 0       {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2       {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...
# 3                                                    None
# 4       {'Monday': '16:0-19:0', 'Tuesday': '16:0-19:0'...
# ...                                                   ...
# 160580  {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...
# 160581  {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
# 160582  {'Monday': '0:0-0:0', 'Wednesday': '12:0-17:0'...
# 160583                                               None
# 160584  {'Tuesday': '17:0-21:0', 'Wednesday': '17:0-21...
#
# [160585 rows x 14 columns]

# %% [markdown]
# We can see that the nested data is located in 'categories', 'attributes' and 'hous' columns. We are going to flatten the 'categories' column in the following cells.

# %%
yelp_json[['categories', 'attributes', 'hours']]
# Out:
#                                                categories  \
# 0       Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2       Antiques, Fashion, Used, Vintage & Consignment...
# 3                              Beauty & Spas, Hair Salons
# 4       Gyms, Active Life, Interval Training Gyms, Fit...
# ...                                                   ...
# 160580  Real Estate, Real Estate Services, Home Servic...
# 160581      Health Markets, Food, Specialty Food, Grocery
# 160582  Arts & Entertainment, Paint & Sip, Art Classes...
# 160583              Cuban, Sandwiches, Restaurants, Cafes
# 160584  Restaurants, Middle Eastern, Mediterranean, Pe...
#
#                                                attributes  \
# 0       {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2       {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3       {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 4       {'GoodForKids': 'False', 'BusinessParking': '{...
# ...                                                   ...
# 160580                                               None
# 160581  {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# 160582  {'DogsAllowed': 'False', 'ByAppointmentOnly': ...
# 160583  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 160584  {'RestaurantsReservations': 'True', 'OutdoorSe...
#
#                                                     hours
# 0       {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2       {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...
# 3                                                    None
# 4       {'Monday': '16:0-19:0', 'Tuesday': '16:0-19:0'...
# ...                                                   ...
# 160580  {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...
# 160581  {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
# 160582  {'Monday': '0:0-0:0', 'Wednesday': '12:0-17:0'...
# 160583                                               None
# 160584  {'Tuesday': '17:0-21:0', 'Wednesday': '17:0-21...
#
# [160585 rows x 3 columns]

# %% [markdown]
# ## COVID data

# %% [markdown]
# After opening the JSON file we see that the data is organized based on the country ISO code. We are only showing Afghanistan data as an example. In the DataFrame below we can see how every column corresponds to a different country.
#
# All the nested data is localed into de data row.

# %%
# path
path_covid = 'G:/Mi unidad/GITHUB/data_science_projects/use_SQL_json_files/owid-covid-data.json'

# open
with open(path_covid) as json_file: 
    covid_json = json.load(json_file) 
    
# we only access data AFG data as a sample
covid_json['AFG']
# Out:
# {'continent': 'Asia',
#  'location': 'Afghanistan',
#  'population': 38928341.0,
#  'population_density': 54.422,
#  'median_age': 18.6,
#  'aged_65_older': 2.581,
#  'aged_70_older': 1.337,
#  'gdp_per_capita': 1803.987,
#  'cardiovasc_death_rate': 597.029,
#  'diabetes_prevalence': 9.59,
#  'handwashing_facilities': 37.746,
#  'hospital_beds_per_thousand': 0.5,
#  'life_expectancy': 64.83,
#  'human_development_index': 0.511,
#  'data': [{'date': '2020-02-24',
#    'total_cases': 1.0,
#    'new_cases': 1.0,
#    'total_cases_per_million': 0.026,
#    'new_cases_per_million': 0.026,
#    'stringency_index': 8.33},
#   {'date': '2020-02-25',
#    'total_cases': 1.0,
#    'new_cases': 0.0,
#    'total_cases_per_million': 0.026,
#    'new_cases_per_million': 0.0,
#    'stringency_index': 8.33},
#   {'date': '2020-02-26',
#    'total_cases': 1.0,
#    'new_cases': 0.0,
#    'total_cases_per_million': 0.026,
#    'new_cases_per_million': 0.0,
#    'stringency_index': 8.33},
#   {'date': '2020-02-27',
#    'total_cases': 1.0,
#    'new_cases': 0.0,
#    'total_cases_per_million': 0.026,
#    'new_cases_per_million': 0.0,
#    'stringency_index': 8.33},
#   {'date': '2020-02-28',
#    'total_cases': 1.0,
#    'new_cases': 0.0,
#    'total_cases_per_million': 0.026,
#    'new_cases_per_million': 0.0,
#    'stringency_index': 8.33},
#   {'date': '2020-02-29',
#    'total_cases': 1.0,
#    'new_cases': 0.0,
#    'new_cases_smoothed': 0.143,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.026,
#    'new_cases_per_million': 0.0,
#    'new_cases_smoothed_per_million': 0.004,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 8.33},
#   {'date': '2020-03-01',
#    'total_cases': 1.0,
#    'new_cases': 0.0,
#    'new_cases_smoothed': 0.143,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.026,
#    'new_cases_per_million': 0.0,
#    'new_cases_smoothed_per_million': 0.004,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-02',
#    'total_cases': 1.0,
#    'new_cases': 0.0,
#    'new_cases_smoothed': 0.0,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.026,
#    'new_cases_per_million': 0.0,
#    'new_cases_smoothed_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-03',
#    'total_cases': 2.0,
#    'new_cases': 1.0,
#    'new_cases_smoothed': 0.143,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.051,
#    'new_cases_per_million': 0.026,
#    'new_cases_smoothed_per_million': 0.004,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-04',
#    'total_cases': 4.0,
#    'new_cases': 2.0,
#    'new_cases_smoothed': 0.429,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.103,
#    'new_cases_per_million': 0.051,
#    'new_cases_smoothed_per_million': 0.011,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-05',
#    'total_cases': 4.0,
#    'new_cases': 0.0,
#    'new_cases_smoothed': 0.429,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.103,
#    'new_cases_per_million': 0.0,
#    'new_cases_smoothed_per_million': 0.011,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-06',
#    'total_cases': 4.0,
#    'new_cases': 0.0,
#    'new_cases_smoothed': 0.429,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.103,
#    'new_cases_per_million': 0.0,
#    'new_cases_smoothed_per_million': 0.011,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-07',
#    'total_cases': 4.0,
#    'new_cases': 0.0,
#    'new_cases_smoothed': 0.429,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.103,
#    'new_cases_per_million': 0.0,
#    'new_cases_smoothed_per_million': 0.011,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-08',
#    'total_cases': 5.0,
#    'new_cases': 1.0,
#    'new_cases_smoothed': 0.571,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.128,
#    'new_cases_per_million': 0.026,
#    'new_cases_smoothed_per_million': 0.015,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-09',
#    'total_cases': 7.0,
#    'new_cases': 2.0,
#    'new_cases_smoothed': 0.857,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.18,
#    'new_cases_per_million': 0.051,
#    'new_cases_smoothed_per_million': 0.022,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-10',
#    'total_cases': 8.0,
#    'new_cases': 1.0,
#    'new_cases_smoothed': 0.857,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.206,
#    'new_cases_per_million': 0.026,
#    'new_cases_smoothed_per_million': 0.022,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-11',
#    'total_cases': 11.0,
#    'new_cases': 3.0,
#    'new_cases_smoothed': 1.0,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.283,
#    'new_cases_per_million': 0.077,
#    'new_cases_smoothed_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-12',
#    'total_cases': 12.0,
#    'new_cases': 1.0,
#    'new_cases_smoothed': 1.143,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.308,
#    'new_cases_per_million': 0.026,
#    'new_cases_smoothed_per_million': 0.029,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-13',
#    'total_cases': 13.0,
#    'new_cases': 1.0,
#    'new_cases_smoothed': 1.286,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.334,
#    'new_cases_per_million': 0.026,
#    'new_cases_smoothed_per_million': 0.033,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 27.78},
#   {'date': '2020-03-14',
#    'total_cases': 15.0,
#    'new_cases': 2.0,
#    'new_cases_smoothed': 1.571,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.385,
#    'new_cases_per_million': 0.051,
#    'new_cases_smoothed_per_million': 0.04,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 38.89},
#   {'date': '2020-03-15',
#    'total_cases': 16.0,
#    'new_cases': 1.0,
#    'new_cases_smoothed': 1.571,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.411,
#    'new_cases_per_million': 0.026,
#    'new_cases_smoothed_per_million': 0.04,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 38.89},
#   {'date': '2020-03-16',
#    'total_cases': 18.0,
#    'new_cases': 2.0,
#    'new_cases_smoothed': 1.571,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.462,
#    'new_cases_per_million': 0.051,
#    'new_cases_smoothed_per_million': 0.04,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 38.89},
#   {'date': '2020-03-17',
#    'total_cases': 20.0,
#    'new_cases': 2.0,
#    'new_cases_smoothed': 1.714,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.514,
#    'new_cases_per_million': 0.051,
#    'new_cases_smoothed_per_million': 0.044,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 38.89},
#   {'date': '2020-03-18',
#    'total_cases': 24.0,
#    'new_cases': 4.0,
#    'new_cases_smoothed': 1.857,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.617,
#    'new_cases_per_million': 0.103,
#    'new_cases_smoothed_per_million': 0.048,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 41.67},
#   {'date': '2020-03-19',
#    'total_cases': 25.0,
#    'new_cases': 1.0,
#    'new_cases_smoothed': 1.857,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.642,
#    'new_cases_per_million': 0.026,
#    'new_cases_smoothed_per_million': 0.048,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 41.67},
#   {'date': '2020-03-20',
#    'total_cases': 29.0,
#    'new_cases': 4.0,
#    'new_cases_smoothed': 2.286,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.745,
#    'new_cases_per_million': 0.103,
#    'new_cases_smoothed_per_million': 0.059,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 41.67},
#   {'date': '2020-03-21',
#    'total_cases': 30.0,
#    'new_cases': 1.0,
#    'new_cases_smoothed': 2.143,
#    'new_deaths_smoothed': 0.0,
#    'total_cases_per_million': 0.771,
#    'new_cases_per_million': 0.026,
#    'new_cases_smoothed_per_million': 0.055,
#    'new_deaths_smoothed_per_million': 0.0,
#    'stringency_index': 41.67},
#   {'date': '2020-03-22',
#    'total_cases': 34.0,
#    'new_cases': 4.0,
#    'new_cases_smoothed': 2.571,
#    'total_deaths': 1.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 0.143,
#    'total_cases_per_million': 0.873,
#    'new_cases_per_million': 0.103,
#    'new_cases_smoothed_per_million': 0.066,
#    'total_deaths_per_million': 0.026,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.004,
#    'stringency_index': 41.67},
#   {'date': '2020-03-23',
#    'total_cases': 41.0,
#    'new_cases': 7.0,
#    'new_cases_smoothed': 3.286,
#    'total_deaths': 1.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.143,
#    'total_cases_per_million': 1.053,
#    'new_cases_per_million': 0.18,
#    'new_cases_smoothed_per_million': 0.084,
#    'total_deaths_per_million': 0.026,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.004,
#    'stringency_index': 41.67},
#   {'date': '2020-03-24',
#    'total_cases': 43.0,
#    'new_cases': 2.0,
#    'new_cases_smoothed': 3.286,
#    'total_deaths': 1.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.143,
#    'total_cases_per_million': 1.105,
#    'new_cases_per_million': 0.051,
#    'new_cases_smoothed_per_million': 0.084,
#    'total_deaths_per_million': 0.026,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.004,
#    'stringency_index': 50.93},
#   {'date': '2020-03-25',
#    'total_cases': 76.0,
#    'new_cases': 33.0,
#    'new_cases_smoothed': 7.429,
#    'total_deaths': 2.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 0.286,
#    'total_cases_per_million': 1.952,
#    'new_cases_per_million': 0.848,
#    'new_cases_smoothed_per_million': 0.191,
#    'total_deaths_per_million': 0.051,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.007,
#    'stringency_index': 59.26},
#   {'date': '2020-03-26',
#    'total_cases': 80.0,
#    'new_cases': 4.0,
#    'new_cases_smoothed': 7.857,
#    'total_deaths': 3.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 0.429,
#    'total_cases_per_million': 2.055,
#    'new_cases_per_million': 0.103,
#    'new_cases_smoothed_per_million': 0.202,
#    'total_deaths_per_million': 0.077,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.011,
#    'stringency_index': 59.26},
#   {'date': '2020-03-27',
#    'total_cases': 91.0,
#    'new_cases': 11.0,
#    'new_cases_smoothed': 8.857,
#    'total_deaths': 3.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.429,
#    'total_cases_per_million': 2.338,
#    'new_cases_per_million': 0.283,
#    'new_cases_smoothed_per_million': 0.228,
#    'total_deaths_per_million': 0.077,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.011,
#    'stringency_index': 59.26},
#   {'date': '2020-03-28',
#    'total_cases': 107.0,
#    'new_cases': 16.0,
#    'new_cases_smoothed': 11.0,
#    'total_deaths': 4.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 0.571,
#    'total_cases_per_million': 2.749,
#    'new_cases_per_million': 0.411,
#    'new_cases_smoothed_per_million': 0.283,
#    'total_deaths_per_million': 0.103,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.015,
#    'stringency_index': 67.59},
#   {'date': '2020-03-29',
#    'total_cases': 118.0,
#    'new_cases': 11.0,
#    'new_cases_smoothed': 12.0,
#    'total_deaths': 4.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.429,
#    'total_cases_per_million': 3.031,
#    'new_cases_per_million': 0.283,
#    'new_cases_smoothed_per_million': 0.308,
#    'total_deaths_per_million': 0.103,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.011,
#    'reproduction_rate': 1.44,
#    'stringency_index': 67.59},
#   {'date': '2020-03-30',
#    'total_cases': 146.0,
#    'new_cases': 28.0,
#    'new_cases_smoothed': 15.0,
#    'total_deaths': 4.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.429,
#    'total_cases_per_million': 3.75,
#    'new_cases_per_million': 0.719,
#    'new_cases_smoothed_per_million': 0.385,
#    'total_deaths_per_million': 0.103,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.011,
#    'reproduction_rate': 1.45,
#    'stringency_index': 67.59},
#   {'date': '2020-03-31',
#    'total_cases': 175.0,
#    'new_cases': 29.0,
#    'new_cases_smoothed': 18.857,
#    'total_deaths': 4.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.429,
#    'total_cases_per_million': 4.495,
#    'new_cases_per_million': 0.745,
#    'new_cases_smoothed_per_million': 0.484,
#    'total_deaths_per_million': 0.103,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.011,
#    'reproduction_rate': 1.46,
#    'stringency_index': 67.59},
#   {'date': '2020-04-01',
#    'total_cases': 197.0,
#    'new_cases': 22.0,
#    'new_cases_smoothed': 17.286,
#    'total_deaths': 4.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.286,
#    'total_cases_per_million': 5.061,
#    'new_cases_per_million': 0.565,
#    'new_cases_smoothed_per_million': 0.444,
#    'total_deaths_per_million': 0.103,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.007,
#    'reproduction_rate': 1.46,
#    'stringency_index': 67.59},
#   {'date': '2020-04-02',
#    'total_cases': 240.0,
#    'new_cases': 43.0,
#    'new_cases_smoothed': 22.857,
#    'total_deaths': 4.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.143,
#    'total_cases_per_million': 6.165,
#    'new_cases_per_million': 1.105,
#    'new_cases_smoothed_per_million': 0.587,
#    'total_deaths_per_million': 0.103,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.004,
#    'reproduction_rate': 1.46,
#    'stringency_index': 67.59},
#   {'date': '2020-04-03',
#    'total_cases': 275.0,
#    'new_cases': 35.0,
#    'new_cases_smoothed': 26.286,
#    'total_deaths': 8.0,
#    'new_deaths': 4.0,
#    'new_deaths_smoothed': 0.714,
#    'total_cases_per_million': 7.064,
#    'new_cases_per_million': 0.899,
#    'new_cases_smoothed_per_million': 0.675,
#    'total_deaths_per_million': 0.206,
#    'new_deaths_per_million': 0.103,
#    'new_deaths_smoothed_per_million': 0.018,
#    'reproduction_rate': 1.45,
#    'stringency_index': 67.59},
#   {'date': '2020-04-04',
#    'total_cases': 300.0,
#    'new_cases': 25.0,
#    'new_cases_smoothed': 27.571,
#    'total_deaths': 10.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 0.857,
#    'total_cases_per_million': 7.706,
#    'new_cases_per_million': 0.642,
#    'new_cases_smoothed_per_million': 0.708,
#    'total_deaths_per_million': 0.257,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.022,
#    'reproduction_rate': 1.43,
#    'stringency_index': 67.59},
#   {'date': '2020-04-05',
#    'total_cases': 338.0,
#    'new_cases': 38.0,
#    'new_cases_smoothed': 31.429,
#    'total_deaths': 12.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 1.143,
#    'total_cases_per_million': 8.683,
#    'new_cases_per_million': 0.976,
#    'new_cases_smoothed_per_million': 0.807,
#    'total_deaths_per_million': 0.308,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.029,
#    'reproduction_rate': 1.43,
#    'stringency_index': 78.7},
#   {'date': '2020-04-06',
#    'total_cases': 368.0,
#    'new_cases': 30.0,
#    'new_cases_smoothed': 31.714,
#    'total_deaths': 15.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 1.571,
#    'total_cases_per_million': 9.453,
#    'new_cases_per_million': 0.771,
#    'new_cases_smoothed_per_million': 0.815,
#    'total_deaths_per_million': 0.385,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.04,
#    'reproduction_rate': 1.42,
#    'stringency_index': 78.7},
#   {'date': '2020-04-07',
#    'total_cases': 424.0,
#    'new_cases': 56.0,
#    'new_cases_smoothed': 35.571,
#    'total_deaths': 16.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.714,
#    'total_cases_per_million': 10.892,
#    'new_cases_per_million': 1.439,
#    'new_cases_smoothed_per_million': 0.914,
#    'total_deaths_per_million': 0.411,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.044,
#    'reproduction_rate': 1.41,
#    'stringency_index': 78.7},
#   {'date': '2020-04-08',
#    'total_cases': 445.0,
#    'new_cases': 21.0,
#    'new_cases_smoothed': 35.429,
#    'total_deaths': 16.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 1.714,
#    'total_cases_per_million': 11.431,
#    'new_cases_per_million': 0.539,
#    'new_cases_smoothed_per_million': 0.91,
#    'total_deaths_per_million': 0.411,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.044,
#    'reproduction_rate': 1.4,
#    'stringency_index': 78.7},
#   {'date': '2020-04-09',
#    'total_cases': 485.0,
#    'new_cases': 40.0,
#    'new_cases_smoothed': 35.0,
#    'total_deaths': 17.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.857,
#    'total_cases_per_million': 12.459,
#    'new_cases_per_million': 1.028,
#    'new_cases_smoothed_per_million': 0.899,
#    'total_deaths_per_million': 0.437,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.048,
#    'reproduction_rate': 1.39,
#    'stringency_index': 78.7},
#   {'date': '2020-04-10',
#    'total_cases': 532.0,
#    'new_cases': 47.0,
#    'new_cases_smoothed': 36.714,
#    'total_deaths': 18.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.429,
#    'total_cases_per_million': 13.666,
#    'new_cases_per_million': 1.207,
#    'new_cases_smoothed_per_million': 0.943,
#    'total_deaths_per_million': 0.462,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.037,
#    'reproduction_rate': 1.39,
#    'stringency_index': 78.7},
#   {'date': '2020-04-11',
#    'total_cases': 556.0,
#    'new_cases': 24.0,
#    'new_cases_smoothed': 36.571,
#    'total_deaths': 18.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 1.143,
#    'total_cases_per_million': 14.283,
#    'new_cases_per_million': 0.617,
#    'new_cases_smoothed_per_million': 0.939,
#    'total_deaths_per_million': 0.462,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.029,
#    'reproduction_rate': 1.39,
#    'stringency_index': 78.7},
#   {'date': '2020-04-12',
#    'total_cases': 608.0,
#    'new_cases': 52.0,
#    'new_cases_smoothed': 38.571,
#    'total_deaths': 19.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.0,
#    'total_cases_per_million': 15.618,
#    'new_cases_per_million': 1.336,
#    'new_cases_smoothed_per_million': 0.991,
#    'total_deaths_per_million': 0.488,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.026,
#    'reproduction_rate': 1.39,
#    'stringency_index': 84.26},
#   {'date': '2020-04-13',
#    'total_cases': 666.0,
#    'new_cases': 58.0,
#    'new_cases_smoothed': 42.571,
#    'total_deaths': 22.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 1.0,
#    'total_cases_per_million': 17.108,
#    'new_cases_per_million': 1.49,
#    'new_cases_smoothed_per_million': 1.094,
#    'total_deaths_per_million': 0.565,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.026,
#    'reproduction_rate': 1.4,
#    'stringency_index': 84.26},
#   {'date': '2020-04-14',
#    'total_cases': 715.0,
#    'new_cases': 49.0,
#    'new_cases_smoothed': 41.571,
#    'total_deaths': 23.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.0,
#    'total_cases_per_million': 18.367,
#    'new_cases_per_million': 1.259,
#    'new_cases_smoothed_per_million': 1.068,
#    'total_deaths_per_million': 0.591,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.026,
#    'reproduction_rate': 1.39,
#    'stringency_index': 84.26},
#   {'date': '2020-04-15',
#    'total_cases': 785.0,
#    'new_cases': 70.0,
#    'new_cases_smoothed': 48.571,
#    'total_deaths': 29.0,
#    'new_deaths': 6.0,
#    'new_deaths_smoothed': 1.857,
#    'total_cases_per_million': 20.165,
#    'new_cases_per_million': 1.798,
#    'new_cases_smoothed_per_million': 1.248,
#    'total_deaths_per_million': 0.745,
#    'new_deaths_per_million': 0.154,
#    'new_deaths_smoothed_per_million': 0.048,
#    'reproduction_rate': 1.39,
#    'stringency_index': 84.26},
#   {'date': '2020-04-16',
#    'total_cases': 841.0,
#    'new_cases': 56.0,
#    'new_cases_smoothed': 50.857,
#    'total_deaths': 30.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.857,
#    'total_cases_per_million': 21.604,
#    'new_cases_per_million': 1.439,
#    'new_cases_smoothed_per_million': 1.306,
#    'total_deaths_per_million': 0.771,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.048,
#    'reproduction_rate': 1.39,
#    'stringency_index': 84.26},
#   {'date': '2020-04-17',
#    'total_cases': 907.0,
#    'new_cases': 66.0,
#    'new_cases_smoothed': 53.571,
#    'total_deaths': 30.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 1.714,
#    'total_cases_per_million': 23.299,
#    'new_cases_per_million': 1.695,
#    'new_cases_smoothed_per_million': 1.376,
#    'total_deaths_per_million': 0.771,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.044,
#    'reproduction_rate': 1.38,
#    'stringency_index': 84.26},
#   {'date': '2020-04-18',
#    'total_cases': 934.0,
#    'new_cases': 27.0,
#    'new_cases_smoothed': 54.0,
#    'total_deaths': 30.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 1.714,
#    'total_cases_per_million': 23.993,
#    'new_cases_per_million': 0.694,
#    'new_cases_smoothed_per_million': 1.387,
#    'total_deaths_per_million': 0.771,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.044,
#    'reproduction_rate': 1.37,
#    'stringency_index': 84.26},
#   {'date': '2020-04-19',
#    'total_cases': 997.0,
#    'new_cases': 63.0,
#    'new_cases_smoothed': 55.571,
#    'total_deaths': 33.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 2.0,
#    'total_cases_per_million': 25.611,
#    'new_cases_per_million': 1.618,
#    'new_cases_smoothed_per_million': 1.428,
#    'total_deaths_per_million': 0.848,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.051,
#    'reproduction_rate': 1.38,
#    'stringency_index': 84.26},
#   {'date': '2020-04-20',
#    'total_cases': 1027.0,
#    'new_cases': 30.0,
#    'new_cases_smoothed': 51.571,
#    'total_deaths': 36.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 2.0,
#    'total_cases_per_million': 26.382,
#    'new_cases_per_million': 0.771,
#    'new_cases_smoothed_per_million': 1.325,
#    'total_deaths_per_million': 0.925,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.051,
#    'reproduction_rate': 1.39,
#    'stringency_index': 84.26},
#   {'date': '2020-04-21',
#    'total_cases': 1093.0,
#    'new_cases': 66.0,
#    'new_cases_smoothed': 54.0,
#    'total_deaths': 36.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 1.857,
#    'total_cases_per_million': 28.077,
#    'new_cases_per_million': 1.695,
#    'new_cases_smoothed_per_million': 1.387,
#    'total_deaths_per_million': 0.925,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.048,
#    'reproduction_rate': 1.42,
#    'stringency_index': 84.26},
#   {'date': '2020-04-22',
#    'total_cases': 1177.0,
#    'new_cases': 84.0,
#    'new_cases_smoothed': 56.0,
#    'total_deaths': 40.0,
#    'new_deaths': 4.0,
#    'new_deaths_smoothed': 1.571,
#    'total_cases_per_million': 30.235,
#    'new_cases_per_million': 2.158,
#    'new_cases_smoothed_per_million': 1.439,
#    'total_deaths_per_million': 1.028,
#    'new_deaths_per_million': 0.103,
#    'new_deaths_smoothed_per_million': 0.04,
#    'reproduction_rate': 1.44,
#    'stringency_index': 84.26},
#   {'date': '2020-04-23',
#    'total_cases': 1236.0,
#    'new_cases': 59.0,
#    'new_cases_smoothed': 56.429,
#    'total_deaths': 40.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 1.429,
#    'total_cases_per_million': 31.751,
#    'new_cases_per_million': 1.516,
#    'new_cases_smoothed_per_million': 1.45,
#    'total_deaths_per_million': 1.028,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.037,
#    'reproduction_rate': 1.46,
#    'stringency_index': 84.26},
#   {'date': '2020-04-24',
#    'total_cases': 1331.0,
#    'new_cases': 95.0,
#    'new_cases_smoothed': 60.571,
#    'total_deaths': 43.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 1.857,
#    'total_cases_per_million': 34.191,
#    'new_cases_per_million': 2.44,
#    'new_cases_smoothed_per_million': 1.556,
#    'total_deaths_per_million': 1.105,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.048,
#    'reproduction_rate': 1.48,
#    'stringency_index': 84.26},
#   {'date': '2020-04-25',
#    'total_cases': 1464.0,
#    'new_cases': 133.0,
#    'new_cases_smoothed': 75.714,
#    'total_deaths': 47.0,
#    'new_deaths': 4.0,
#    'new_deaths_smoothed': 2.429,
#    'total_cases_per_million': 37.608,
#    'new_cases_per_million': 3.417,
#    'new_cases_smoothed_per_million': 1.945,
#    'total_deaths_per_million': 1.207,
#    'new_deaths_per_million': 0.103,
#    'new_deaths_smoothed_per_million': 0.062,
#    'reproduction_rate': 1.5,
#    'stringency_index': 84.26},
#   {'date': '2020-04-26',
#    'total_cases': 1532.0,
#    'new_cases': 68.0,
#    'new_cases_smoothed': 76.429,
#    'total_deaths': 52.0,
#    'new_deaths': 5.0,
#    'new_deaths_smoothed': 2.714,
#    'total_cases_per_million': 39.354,
#    'new_cases_per_million': 1.747,
#    'new_cases_smoothed_per_million': 1.963,
#    'total_deaths_per_million': 1.336,
#    'new_deaths_per_million': 0.128,
#    'new_deaths_smoothed_per_million': 0.07,
#    'reproduction_rate': 1.5,
#    'stringency_index': 84.26},
#   {'date': '2020-04-27',
#    'total_cases': 1704.0,
#    'new_cases': 172.0,
#    'new_cases_smoothed': 96.714,
#    'total_deaths': 58.0,
#    'new_deaths': 6.0,
#    'new_deaths_smoothed': 3.143,
#    'total_cases_per_million': 43.773,
#    'new_cases_per_million': 4.418,
#    'new_cases_smoothed_per_million': 2.484,
#    'total_deaths_per_million': 1.49,
#    'new_deaths_per_million': 0.154,
#    'new_deaths_smoothed_per_million': 0.081,
#    'reproduction_rate': 1.52,
#    'stringency_index': 84.26},
#   {'date': '2020-04-28',
#    'total_cases': 1830.0,
#    'new_cases': 126.0,
#    'new_cases_smoothed': 105.286,
#    'total_deaths': 59.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 3.286,
#    'total_cases_per_million': 47.009,
#    'new_cases_per_million': 3.237,
#    'new_cases_smoothed_per_million': 2.705,
#    'total_deaths_per_million': 1.516,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.084,
#    'reproduction_rate': 1.52,
#    'stringency_index': 84.26},
#   {'date': '2020-04-29',
#    'total_cases': 1940.0,
#    'new_cases': 110.0,
#    'new_cases_smoothed': 109.0,
#    'total_deaths': 61.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 3.0,
#    'total_cases_per_million': 49.835,
#    'new_cases_per_million': 2.826,
#    'new_cases_smoothed_per_million': 2.8,
#    'total_deaths_per_million': 1.567,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.077,
#    'reproduction_rate': 1.52,
#    'stringency_index': 84.26},
#   {'date': '2020-04-30',
#    'total_cases': 2127.0,
#    'new_cases': 187.0,
#    'new_cases_smoothed': 127.286,
#    'total_deaths': 64.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 3.429,
#    'total_cases_per_million': 54.639,
#    'new_cases_per_million': 4.804,
#    'new_cases_smoothed_per_million': 3.27,
#    'total_deaths_per_million': 1.644,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.088,
#    'reproduction_rate': 1.52,
#    'stringency_index': 84.26},
#   {'date': '2020-05-01',
#    'total_cases': 2291.0,
#    'new_cases': 164.0,
#    'new_cases_smoothed': 137.143,
#    'total_deaths': 68.0,
#    'new_deaths': 4.0,
#    'new_deaths_smoothed': 3.571,
#    'total_cases_per_million': 58.852,
#    'new_cases_per_million': 4.213,
#    'new_cases_smoothed_per_million': 3.523,
#    'total_deaths_per_million': 1.747,
#    'new_deaths_per_million': 0.103,
#    'new_deaths_smoothed_per_million': 0.092,
#    'reproduction_rate': 1.52,
#    'stringency_index': 84.26},
#   {'date': '2020-05-02',
#    'total_cases': 2470.0,
#    'new_cases': 179.0,
#    'new_cases_smoothed': 143.714,
#    'total_deaths': 72.0,
#    'new_deaths': 4.0,
#    'new_deaths_smoothed': 3.571,
#    'total_cases_per_million': 63.45,
#    'new_cases_per_million': 4.598,
#    'new_cases_smoothed_per_million': 3.692,
#    'total_deaths_per_million': 1.85,
#    'new_deaths_per_million': 0.103,
#    'new_deaths_smoothed_per_million': 0.092,
#    'reproduction_rate': 1.51,
#    'stringency_index': 84.26},
#   {'date': '2020-05-03',
#    'total_cases': 2705.0,
#    'new_cases': 235.0,
#    'new_cases_smoothed': 167.571,
#    'total_deaths': 85.0,
#    'new_deaths': 13.0,
#    'new_deaths_smoothed': 4.714,
#    'total_cases_per_million': 69.487,
#    'new_cases_per_million': 6.037,
#    'new_cases_smoothed_per_million': 4.305,
#    'total_deaths_per_million': 2.183,
#    'new_deaths_per_million': 0.334,
#    'new_deaths_smoothed_per_million': 0.121,
#    'reproduction_rate': 1.51,
#    'stringency_index': 84.26},
#   {'date': '2020-05-04',
#    'total_cases': 2895.0,
#    'new_cases': 190.0,
#    'new_cases_smoothed': 170.143,
#    'total_deaths': 90.0,
#    'new_deaths': 5.0,
#    'new_deaths_smoothed': 4.571,
#    'total_cases_per_million': 74.367,
#    'new_cases_per_million': 4.881,
#    'new_cases_smoothed_per_million': 4.371,
#    'total_deaths_per_million': 2.312,
#    'new_deaths_per_million': 0.128,
#    'new_deaths_smoothed_per_million': 0.117,
#    'reproduction_rate': 1.5,
#    'stringency_index': 84.26},
#   {'date': '2020-05-05',
#    'total_cases': 3225.0,
#    'new_cases': 330.0,
#    'new_cases_smoothed': 199.286,
#    'total_deaths': 95.0,
#    'new_deaths': 5.0,
#    'new_deaths_smoothed': 5.143,
#    'total_cases_per_million': 82.845,
#    'new_cases_per_million': 8.477,
#    'new_cases_smoothed_per_million': 5.119,
#    'total_deaths_per_million': 2.44,
#    'new_deaths_per_million': 0.128,
#    'new_deaths_smoothed_per_million': 0.132,
#    'reproduction_rate': 1.49,
#    'stringency_index': 84.26},
#   {'date': '2020-05-06',
#    'total_cases': 3393.0,
#    'new_cases': 168.0,
#    'new_cases_smoothed': 207.571,
#    'total_deaths': 104.0,
#    'new_deaths': 9.0,
#    'new_deaths_smoothed': 6.143,
#    'total_cases_per_million': 87.16,
#    'new_cases_per_million': 4.316,
#    'new_cases_smoothed_per_million': 5.332,
#    'total_deaths_per_million': 2.672,
#    'new_deaths_per_million': 0.231,
#    'new_deaths_smoothed_per_million': 0.158,
#    'reproduction_rate': 1.46,
#    'stringency_index': 84.26},
#   {'date': '2020-05-07',
#    'total_cases': 3564.0,
#    'new_cases': 171.0,
#    'new_cases_smoothed': 205.286,
#    'total_deaths': 106.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 6.0,
#    'total_cases_per_million': 91.553,
#    'new_cases_per_million': 4.393,
#    'new_cases_smoothed_per_million': 5.273,
#    'total_deaths_per_million': 2.723,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.154,
#    'reproduction_rate': 1.44,
#    'stringency_index': 84.26},
#   {'date': '2020-05-08',
#    'total_cases': 3781.0,
#    'new_cases': 217.0,
#    'new_cases_smoothed': 212.857,
#    'total_deaths': 109.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 5.857,
#    'total_cases_per_million': 97.127,
#    'new_cases_per_million': 5.574,
#    'new_cases_smoothed_per_million': 5.468,
#    'total_deaths_per_million': 2.8,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.15,
#    'reproduction_rate': 1.44,
#    'stringency_index': 84.26},
#   {'date': '2020-05-09',
#    'total_cases': 4042.0,
#    'new_cases': 261.0,
#    'new_cases_smoothed': 224.571,
#    'total_deaths': 115.0,
#    'new_deaths': 6.0,
#    'new_deaths_smoothed': 6.143,
#    'total_cases_per_million': 103.832,
#    'new_cases_per_million': 6.705,
#    'new_cases_smoothed_per_million': 5.769,
#    'total_deaths_per_million': 2.954,
#    'new_deaths_per_million': 0.154,
#    'new_deaths_smoothed_per_million': 0.158,
#    'reproduction_rate': 1.44,
#    'stringency_index': 84.26},
#   {'date': '2020-05-10',
#    'total_cases': 4403.0,
#    'new_cases': 361.0,
#    'new_cases_smoothed': 242.571,
#    'total_deaths': 120.0,
#    'new_deaths': 5.0,
#    'new_deaths_smoothed': 5.0,
#    'total_cases_per_million': 113.105,
#    'new_cases_per_million': 9.273,
#    'new_cases_smoothed_per_million': 6.231,
#    'total_deaths_per_million': 3.083,
#    'new_deaths_per_million': 0.128,
#    'new_deaths_smoothed_per_million': 0.128,
#    'reproduction_rate': 1.43,
#    'stringency_index': 84.26},
#   {'date': '2020-05-11',
#    'total_cases': 4687.0,
#    'new_cases': 284.0,
#    'new_cases_smoothed': 256.0,
#    'total_deaths': 122.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 4.571,
#    'total_cases_per_million': 120.401,
#    'new_cases_per_million': 7.295,
#    'new_cases_smoothed_per_million': 6.576,
#    'total_deaths_per_million': 3.134,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.117,
#    'reproduction_rate': 1.42,
#    'stringency_index': 84.26},
#   {'date': '2020-05-12',
#    'total_cases': 4968.0,
#    'new_cases': 281.0,
#    'new_cases_smoothed': 249.0,
#    'total_deaths': 127.0,
#    'new_deaths': 5.0,
#    'new_deaths_smoothed': 4.571,
#    'total_cases_per_million': 127.619,
#    'new_cases_per_million': 7.218,
#    'new_cases_smoothed_per_million': 6.396,
#    'total_deaths_per_million': 3.262,
#    'new_deaths_per_million': 0.128,
#    'new_deaths_smoothed_per_million': 0.117,
#    'reproduction_rate': 1.41,
#    'stringency_index': 84.26},
#   {'date': '2020-05-13',
#    'total_cases': 5227.0,
#    'new_cases': 259.0,
#    'new_cases_smoothed': 262.0,
#    'total_deaths': 132.0,
#    'new_deaths': 5.0,
#    'new_deaths_smoothed': 4.0,
#    'total_cases_per_million': 134.272,
#    'new_cases_per_million': 6.653,
#    'new_cases_smoothed_per_million': 6.73,
#    'total_deaths_per_million': 3.391,
#    'new_deaths_per_million': 0.128,
#    'new_deaths_smoothed_per_million': 0.103,
#    'reproduction_rate': 1.41,
#    'stringency_index': 84.26},
#   {'date': '2020-05-14',
#    'total_cases': 5640.0,
#    'new_cases': 413.0,
#    'new_cases_smoothed': 296.571,
#    'total_deaths': 136.0,
#    'new_deaths': 4.0,
#    'new_deaths_smoothed': 4.286,
#    'total_cases_per_million': 144.882,
#    'new_cases_per_million': 10.609,
#    'new_cases_smoothed_per_million': 7.618,
#    'total_deaths_per_million': 3.494,
#    'new_deaths_per_million': 0.103,
#    'new_deaths_smoothed_per_million': 0.11,
#    'reproduction_rate': 1.41,
#    'stringency_index': 84.26},
#   {'date': '2020-05-15',
#    'total_cases': 6054.0,
#    'new_cases': 414.0,
#    'new_cases_smoothed': 324.714,
#    'total_deaths': 153.0,
#    'new_deaths': 17.0,
#    'new_deaths_smoothed': 6.286,
#    'total_cases_per_million': 155.517,
#    'new_cases_per_million': 10.635,
#    'new_cases_smoothed_per_million': 8.341,
#    'total_deaths_per_million': 3.93,
#    'new_deaths_per_million': 0.437,
#    'new_deaths_smoothed_per_million': 0.161,
#    'reproduction_rate': 1.4,
#    'stringency_index': 84.26},
#   {'date': '2020-05-16',
#    'total_cases': 6403.0,
#    'new_cases': 349.0,
#    'new_cases_smoothed': 337.286,
#    'total_deaths': 168.0,
#    'new_deaths': 15.0,
#    'new_deaths_smoothed': 7.571,
#    'total_cases_per_million': 164.482,
#    'new_cases_per_million': 8.965,
#    'new_cases_smoothed_per_million': 8.664,
#    'total_deaths_per_million': 4.316,
#    'new_deaths_per_million': 0.385,
#    'new_deaths_smoothed_per_million': 0.194,
#    'reproduction_rate': 1.39,
#    'stringency_index': 84.26},
#   {'date': '2020-05-17',
#    'total_cases': 6665.0,
#    'new_cases': 262.0,
#    'new_cases_smoothed': 323.143,
#    'total_deaths': 170.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 7.143,
#    'total_cases_per_million': 171.212,
#    'new_cases_per_million': 6.73,
#    'new_cases_smoothed_per_million': 8.301,
#    'total_deaths_per_million': 4.367,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.183,
#    'reproduction_rate': 1.38,
#    'stringency_index': 84.26},
#   {'date': '2020-05-18',
#    'total_cases': 7073.0,
#    'new_cases': 408.0,
#    'new_cases_smoothed': 340.857,
#    'total_deaths': 173.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 7.286,
#    'total_cases_per_million': 181.693,
#    'new_cases_per_million': 10.481,
#    'new_cases_smoothed_per_million': 8.756,
#    'total_deaths_per_million': 4.444,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.187,
#    'reproduction_rate': 1.38,
#    'stringency_index': 84.26},
#   {'date': '2020-05-19',
#    'total_cases': 7654.0,
#    'new_cases': 581.0,
#    'new_cases_smoothed': 383.714,
#    'total_deaths': 178.0,
#    'new_deaths': 5.0,
#    'new_deaths_smoothed': 7.286,
#    'total_cases_per_million': 196.618,
#    'new_cases_per_million': 14.925,
#    'new_cases_smoothed_per_million': 9.857,
#    'total_deaths_per_million': 4.573,
#    'new_deaths_per_million': 0.128,
#    'new_deaths_smoothed_per_million': 0.187,
#    'reproduction_rate': 1.38,
#    'stringency_index': 84.26},
#   {'date': '2020-05-20',
#    'total_cases': 8146.0,
#    'new_cases': 492.0,
#    'new_cases_smoothed': 417.0,
#    'total_deaths': 188.0,
#    'new_deaths': 10.0,
#    'new_deaths_smoothed': 8.0,
#    'total_cases_per_million': 209.256,
#    'new_cases_per_million': 12.639,
#    'new_cases_smoothed_per_million': 10.712,
#    'total_deaths_per_million': 4.829,
#    'new_deaths_per_million': 0.257,
#    'new_deaths_smoothed_per_million': 0.206,
#    'reproduction_rate': 1.38,
#    'stringency_index': 84.26},
#   {'date': '2020-05-21',
#    'total_cases': 8677.0,
#    'new_cases': 531.0,
#    'new_cases_smoothed': 433.857,
#    'total_deaths': 194.0,
#    'new_deaths': 6.0,
#    'new_deaths_smoothed': 8.286,
#    'total_cases_per_million': 222.897,
#    'new_cases_per_million': 13.64,
#    'new_cases_smoothed_per_million': 11.145,
#    'total_deaths_per_million': 4.984,
#    'new_deaths_per_million': 0.154,
#    'new_deaths_smoothed_per_million': 0.213,
#    'reproduction_rate': 1.37,
#    'stringency_index': 84.26},
#   {'date': '2020-05-22',
#    'total_cases': 9219.0,
#    'new_cases': 542.0,
#    'new_cases_smoothed': 452.143,
#    'total_deaths': 206.0,
#    'new_deaths': 12.0,
#    'new_deaths_smoothed': 7.571,
#    'total_cases_per_million': 236.82,
#    'new_cases_per_million': 13.923,
#    'new_cases_smoothed_per_million': 11.615,
#    'total_deaths_per_million': 5.292,
#    'new_deaths_per_million': 0.308,
#    'new_deaths_smoothed_per_million': 0.194,
#    'reproduction_rate': 1.36,
#    'stringency_index': 84.26},
#   {'date': '2020-05-23',
#    'total_cases': 10001.0,
#    'new_cases': 782.0,
#    'new_cases_smoothed': 514.0,
#    'total_deaths': 217.0,
#    'new_deaths': 11.0,
#    'new_deaths_smoothed': 7.0,
#    'total_cases_per_million': 256.908,
#    'new_cases_per_million': 20.088,
#    'new_cases_smoothed_per_million': 13.204,
#    'total_deaths_per_million': 5.574,
#    'new_deaths_per_million': 0.283,
#    'new_deaths_smoothed_per_million': 0.18,
#    'reproduction_rate': 1.35,
#    'stringency_index': 84.26},
#   {'date': '2020-05-24',
#    'total_cases': 10585.0,
#    'new_cases': 584.0,
#    'new_cases_smoothed': 560.0,
#    'total_deaths': 219.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 7.0,
#    'total_cases_per_million': 271.91,
#    'new_cases_per_million': 15.002,
#    'new_cases_smoothed_per_million': 14.385,
#    'total_deaths_per_million': 5.626,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.18,
#    'reproduction_rate': 1.32,
#    'stringency_index': 84.26},
#   {'date': '2020-05-25',
#    'total_cases': 11176.0,
#    'new_cases': 591.0,
#    'new_cases_smoothed': 586.143,
#    'total_deaths': 220.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 6.714,
#    'total_cases_per_million': 287.092,
#    'new_cases_per_million': 15.182,
#    'new_cases_smoothed_per_million': 15.057,
#    'total_deaths_per_million': 5.651,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.172,
#    'reproduction_rate': 1.3,
#    'stringency_index': 84.26},
#   {'date': '2020-05-26',
#    'total_cases': 11834.0,
#    'new_cases': 658.0,
#    'new_cases_smoothed': 597.143,
#    'total_deaths': 221.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 6.143,
#    'total_cases_per_million': 303.994,
#    'new_cases_per_million': 16.903,
#    'new_cases_smoothed_per_million': 15.34,
#    'total_deaths_per_million': 5.677,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.158,
#    'reproduction_rate': 1.28,
#    'stringency_index': 84.26},
#   {'date': '2020-05-27',
#    'total_cases': 12459.0,
#    'new_cases': 625.0,
#    'new_cases_smoothed': 616.143,
#    'total_deaths': 228.0,
#    'new_deaths': 7.0,
#    'new_deaths_smoothed': 5.714,
#    'total_cases_per_million': 320.05,
#    'new_cases_per_million': 16.055,
#    'new_cases_smoothed_per_million': 15.828,
#    'total_deaths_per_million': 5.857,
#    'new_deaths_per_million': 0.18,
#    'new_deaths_smoothed_per_million': 0.147,
#    'reproduction_rate': 1.26,
#    'stringency_index': 84.26},
#   {'date': '2020-05-28',
#    'total_cases': 13039.0,
#    'new_cases': 580.0,
#    'new_cases_smoothed': 623.143,
#    'total_deaths': 236.0,
#    'new_deaths': 8.0,
#    'new_deaths_smoothed': 6.0,
#    'total_cases_per_million': 334.949,
#    'new_cases_per_million': 14.899,
#    'new_cases_smoothed_per_million': 16.007,
#    'total_deaths_per_million': 6.062,
#    'new_deaths_per_million': 0.206,
#    'new_deaths_smoothed_per_million': 0.154,
#    'reproduction_rate': 1.24,
#    'stringency_index': 84.26},
#   {'date': '2020-05-29',
#    'total_cases': 13662.0,
#    'new_cases': 623.0,
#    'new_cases_smoothed': 634.714,
#    'total_deaths': 247.0,
#    'new_deaths': 11.0,
#    'new_deaths_smoothed': 5.857,
#    'total_cases_per_million': 350.953,
#    'new_cases_per_million': 16.004,
#    'new_cases_smoothed_per_million': 16.305,
#    'total_deaths_per_million': 6.345,
#    'new_deaths_per_million': 0.283,
#    'new_deaths_smoothed_per_million': 0.15,
#    'reproduction_rate': 1.23,
#    'stringency_index': 84.26},
#   {'date': '2020-05-30',
#    'total_cases': 14528.0,
#    'new_cases': 866.0,
#    'new_cases_smoothed': 646.714,
#    'total_deaths': 250.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 4.714,
#    'total_cases_per_million': 373.199,
#    'new_cases_per_million': 22.246,
#    'new_cases_smoothed_per_million': 16.613,
#    'total_deaths_per_million': 6.422,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.121,
#    'reproduction_rate': 1.21,
#    'stringency_index': 84.26},
#   {'date': '2020-05-31',
#    'total_cases': 15208.0,
#    'new_cases': 680.0,
#    'new_cases_smoothed': 660.429,
#    'total_deaths': 258.0,
#    'new_deaths': 8.0,
#    'new_deaths_smoothed': 5.571,
#    'total_cases_per_million': 390.667,
#    'new_cases_per_million': 17.468,
#    'new_cases_smoothed_per_million': 16.965,
#    'total_deaths_per_million': 6.628,
#    'new_deaths_per_million': 0.206,
#    'new_deaths_smoothed_per_million': 0.143,
#    'reproduction_rate': 1.19,
#    'stringency_index': 84.26},
#   {'date': '2020-06-01',
#    'total_cases': 15753.0,
#    'new_cases': 545.0,
#    'new_cases_smoothed': 653.857,
#    'total_deaths': 266.0,
#    'new_deaths': 8.0,
#    'new_deaths_smoothed': 6.571,
#    'total_cases_per_million': 404.667,
#    'new_cases_per_million': 14.0,
#    'new_cases_smoothed_per_million': 16.796,
#    'total_deaths_per_million': 6.833,
#    'new_deaths_per_million': 0.206,
#    'new_deaths_smoothed_per_million': 0.169,
#    'reproduction_rate': 1.17,
#    'stringency_index': 84.26},
#   {'date': '2020-06-02',
#    'total_cases': 16512.0,
#    'new_cases': 759.0,
#    'new_cases_smoothed': 668.286,
#    'total_deaths': 274.0,
#    'new_deaths': 8.0,
#    'new_deaths_smoothed': 7.571,
#    'total_cases_per_million': 424.164,
#    'new_cases_per_million': 19.497,
#    'new_cases_smoothed_per_million': 17.167,
#    'total_deaths_per_million': 7.039,
#    'new_deaths_per_million': 0.206,
#    'new_deaths_smoothed_per_million': 0.194,
#    'reproduction_rate': 1.16,
#    'stringency_index': 84.26},
#   {'date': '2020-06-03',
#    'total_cases': 17270.0,
#    'new_cases': 758.0,
#    'new_cases_smoothed': 687.286,
#    'total_deaths': 298.0,
#    'new_deaths': 24.0,
#    'new_deaths_smoothed': 10.0,
#    'total_cases_per_million': 443.636,
#    'new_cases_per_million': 19.472,
#    'new_cases_smoothed_per_million': 17.655,
#    'total_deaths_per_million': 7.655,
#    'new_deaths_per_million': 0.617,
#    'new_deaths_smoothed_per_million': 0.257,
#    'reproduction_rate': 1.15,
#    'stringency_index': 84.26},
#   {'date': '2020-06-04',
#    'total_cases': 18057.0,
#    'new_cases': 787.0,
#    'new_cases_smoothed': 716.857,
#    'total_deaths': 304.0,
#    'new_deaths': 6.0,
#    'new_deaths_smoothed': 9.714,
#    'total_cases_per_million': 463.852,
#    'new_cases_per_million': 20.217,
#    'new_cases_smoothed_per_million': 18.415,
#    'total_deaths_per_million': 7.809,
#    'new_deaths_per_million': 0.154,
#    'new_deaths_smoothed_per_million': 0.25,
#    'reproduction_rate': 1.13,
#    'stringency_index': 84.26},
#   {'date': '2020-06-05',
#    'total_cases': 18972.0,
#    'new_cases': 915.0,
#    'new_cases_smoothed': 758.571,
#    'total_deaths': 313.0,
#    'new_deaths': 9.0,
#    'new_deaths_smoothed': 9.429,
#    'total_cases_per_million': 487.357,
#    'new_cases_per_million': 23.505,
#    'new_cases_smoothed_per_million': 19.486,
#    'total_deaths_per_million': 8.04,
#    'new_deaths_per_million': 0.231,
#    'new_deaths_smoothed_per_million': 0.242,
#    'reproduction_rate': 1.11,
#    'stringency_index': 84.26},
#   {'date': '2020-06-06',
#    'total_cases': 19554.0,
#    'new_cases': 582.0,
#    'new_cases_smoothed': 718.0,
#    'total_deaths': 331.0,
#    'new_deaths': 18.0,
#    'new_deaths_smoothed': 11.571,
#    'total_cases_per_million': 502.308,
#    'new_cases_per_million': 14.951,
#    'new_cases_smoothed_per_million': 18.444,
#    'total_deaths_per_million': 8.503,
#    'new_deaths_per_million': 0.462,
#    'new_deaths_smoothed_per_million': 0.297,
#    'reproduction_rate': 1.08,
#    'stringency_index': 84.26},
#   {'date': '2020-06-07',
#    'total_cases': 20345.0,
#    'new_cases': 791.0,
#    'new_cases_smoothed': 733.857,
#    'total_deaths': 361.0,
#    'new_deaths': 30.0,
#    'new_deaths_smoothed': 14.714,
#    'total_cases_per_million': 522.627,
#    'new_cases_per_million': 20.319,
#    'new_cases_smoothed_per_million': 18.851,
#    'total_deaths_per_million': 9.273,
#    'new_deaths_per_million': 0.771,
#    'new_deaths_smoothed_per_million': 0.378,
#    'reproduction_rate': 1.06,
#    'stringency_index': 84.26},
#   {'date': '2020-06-08',
#    'total_cases': 20920.0,
#    'new_cases': 575.0,
#    'new_cases_smoothed': 738.143,
#    'total_deaths': 373.0,
#    'new_deaths': 12.0,
#    'new_deaths_smoothed': 15.286,
#    'total_cases_per_million': 537.398,
#    'new_cases_per_million': 14.771,
#    'new_cases_smoothed_per_million': 18.962,
#    'total_deaths_per_million': 9.582,
#    'new_deaths_per_million': 0.308,
#    'new_deaths_smoothed_per_million': 0.393,
#    'reproduction_rate': 1.04,
#    'stringency_index': 84.26},
#   {'date': '2020-06-09',
#    'total_cases': 21462.0,
#    'new_cases': 542.0,
#    'new_cases_smoothed': 707.143,
#    'total_deaths': 388.0,
#    'new_deaths': 15.0,
#    'new_deaths_smoothed': 16.286,
#    'total_cases_per_million': 551.321,
#    'new_cases_per_million': 13.923,
#    'new_cases_smoothed_per_million': 18.165,
#    'total_deaths_per_million': 9.967,
#    'new_deaths_per_million': 0.385,
#    'new_deaths_smoothed_per_million': 0.418,
#    'reproduction_rate': 1.02,
#    'stringency_index': 78.7},
#   {'date': '2020-06-10',
#    'total_cases': 22146.0,
#    'new_cases': 684.0,
#    'new_cases_smoothed': 696.571,
#    'total_deaths': 409.0,
#    'new_deaths': 21.0,
#    'new_deaths_smoothed': 15.857,
#    'total_cases_per_million': 568.891,
#    'new_cases_per_million': 17.571,
#    'new_cases_smoothed_per_million': 17.894,
#    'total_deaths_per_million': 10.506,
#    'new_deaths_per_million': 0.539,
#    'new_deaths_smoothed_per_million': 0.407,
#    'reproduction_rate': 1.01,
#    'stringency_index': 78.7},
#   {'date': '2020-06-11',
#    'total_cases': 22894.0,
#    'new_cases': 748.0,
#    'new_cases_smoothed': 691.0,
#    'total_deaths': 430.0,
#    'new_deaths': 21.0,
#    'new_deaths_smoothed': 18.0,
#    'total_cases_per_million': 588.106,
#    'new_cases_per_million': 19.215,
#    'new_cases_smoothed_per_million': 17.751,
#    'total_deaths_per_million': 11.046,
#    'new_deaths_per_million': 0.539,
#    'new_deaths_smoothed_per_million': 0.462,
#    'reproduction_rate': 1.0,
#    'stringency_index': 78.7},
#   {'date': '2020-06-12',
#    'total_cases': 23550.0,
#    'new_cases': 656.0,
#    'new_cases_smoothed': 654.0,
#    'total_deaths': 450.0,
#    'new_deaths': 20.0,
#    'new_deaths_smoothed': 19.571,
#    'total_cases_per_million': 604.958,
# ...
#    'new_deaths_smoothed': 7.571,
#    'total_cases_per_million': 1394.306,
#    'new_cases_per_million': 3.519,
#    'new_cases_smoothed_per_million': 2.547,
#    'total_deaths_per_million': 60.47,
#    'new_deaths_per_million': 0.206,
#    'new_deaths_smoothed_per_million': 0.194,
#    'reproduction_rate': 0.74,
#    'stringency_index': 12.04},
#   {'date': '2021-01-21',
#    'total_cases': 54403.0,
#    'new_cases': 125.0,
#    'new_cases_smoothed': 89.714,
#    'total_deaths': 2363.0,
#    'new_deaths': 9.0,
#    'new_deaths_smoothed': 7.0,
#    'total_cases_per_million': 1397.517,
#    'new_cases_per_million': 3.211,
#    'new_cases_smoothed_per_million': 2.305,
#    'total_deaths_per_million': 60.701,
#    'new_deaths_per_million': 0.231,
#    'new_deaths_smoothed_per_million': 0.18,
#    'reproduction_rate': 0.74,
#    'stringency_index': 12.04},
#   {'date': '2021-01-22',
#    'total_cases': 54483.0,
#    'new_cases': 80.0,
#    'new_cases_smoothed': 93.143,
#    'total_deaths': 2370.0,
#    'new_deaths': 7.0,
#    'new_deaths_smoothed': 6.571,
#    'total_cases_per_million': 1399.572,
#    'new_cases_per_million': 2.055,
#    'new_cases_smoothed_per_million': 2.393,
#    'total_deaths_per_million': 60.881,
#    'new_deaths_per_million': 0.18,
#    'new_deaths_smoothed_per_million': 0.169,
#    'reproduction_rate': 0.74,
#    'stringency_index': 12.04},
#   {'date': '2021-01-23',
#    'total_cases': 54559.0,
#    'new_cases': 76.0,
#    'new_cases_smoothed': 88.714,
#    'total_deaths': 2373.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 5.286,
#    'total_cases_per_million': 1401.524,
#    'new_cases_per_million': 1.952,
#    'new_cases_smoothed_per_million': 2.279,
#    'total_deaths_per_million': 60.958,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.136,
#    'reproduction_rate': 0.73,
#    'stringency_index': 12.04},
#   {'date': '2021-01-24',
#    'total_cases': 54595.0,
#    'new_cases': 36.0,
#    'new_cases_smoothed': 87.286,
#    'total_deaths': 2378.0,
#    'new_deaths': 5.0,
#    'new_deaths_smoothed': 5.571,
#    'total_cases_per_million': 1402.449,
#    'new_cases_per_million': 0.925,
#    'new_cases_smoothed_per_million': 2.242,
#    'total_deaths_per_million': 61.087,
#    'new_deaths_per_million': 0.128,
#    'new_deaths_smoothed_per_million': 0.143,
#    'reproduction_rate': 0.72,
#    'stringency_index': 12.04},
#   {'date': '2021-01-25',
#    'total_cases': 54672.0,
#    'new_cases': 77.0,
#    'new_cases_smoothed': 87.143,
#    'total_deaths': 2385.0,
#    'new_deaths': 7.0,
#    'new_deaths_smoothed': 6.0,
#    'total_cases_per_million': 1404.427,
#    'new_cases_per_million': 1.978,
#    'new_cases_smoothed_per_million': 2.239,
#    'total_deaths_per_million': 61.266,
#    'new_deaths_per_million': 0.18,
#    'new_deaths_smoothed_per_million': 0.154,
#    'reproduction_rate': 0.72,
#    'stringency_index': 12.04},
#   {'date': '2021-01-26',
#    'total_cases': 54750.0,
#    'new_cases': 78.0,
#    'new_cases_smoothed': 87.0,
#    'total_deaths': 2389.0,
#    'new_deaths': 4.0,
#    'new_deaths_smoothed': 6.143,
#    'total_cases_per_million': 1406.43,
#    'new_cases_per_million': 2.004,
#    'new_cases_smoothed_per_million': 2.235,
#    'total_deaths_per_million': 61.369,
#    'new_deaths_per_million': 0.103,
#    'new_deaths_smoothed_per_million': 0.158,
#    'reproduction_rate': 0.72,
#    'stringency_index': 12.04},
#   {'date': '2021-01-27',
#    'total_cases': 54854.0,
#    'new_cases': 104.0,
#    'new_cases_smoothed': 82.286,
#    'total_deaths': 2389.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 5.0,
#    'total_cases_per_million': 1409.102,
#    'new_cases_per_million': 2.672,
#    'new_cases_smoothed_per_million': 2.114,
#    'total_deaths_per_million': 61.369,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.128,
#    'reproduction_rate': 0.72,
#    'stringency_index': 12.04},
#   {'date': '2021-01-28',
#    'total_cases': 54891.0,
#    'new_cases': 37.0,
#    'new_cases_smoothed': 69.714,
#    'total_deaths': 2397.0,
#    'new_deaths': 8.0,
#    'new_deaths_smoothed': 4.857,
#    'total_cases_per_million': 1410.052,
#    'new_cases_per_million': 0.95,
#    'new_cases_smoothed_per_million': 1.791,
#    'total_deaths_per_million': 61.575,
#    'new_deaths_per_million': 0.206,
#    'new_deaths_smoothed_per_million': 0.125,
#    'reproduction_rate': 0.7,
#    'stringency_index': 12.04},
#   {'date': '2021-01-29',
#    'total_cases': 54939.0,
#    'new_cases': 48.0,
#    'new_cases_smoothed': 65.143,
#    'total_deaths': 2399.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 4.143,
#    'total_cases_per_million': 1411.285,
#    'new_cases_per_million': 1.233,
#    'new_cases_smoothed_per_million': 1.673,
#    'total_deaths_per_million': 61.626,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.106,
#    'reproduction_rate': 0.7,
#    'stringency_index': 12.04},
#   {'date': '2021-01-30',
#    'total_cases': 55008.0,
#    'new_cases': 69.0,
#    'new_cases_smoothed': 64.143,
#    'total_deaths': 2400.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 3.857,
#    'total_cases_per_million': 1413.058,
#    'new_cases_per_million': 1.772,
#    'new_cases_smoothed_per_million': 1.648,
#    'total_deaths_per_million': 61.652,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.099,
#    'reproduction_rate': 0.69,
#    'stringency_index': 12.04},
#   {'date': '2021-01-31',
#    'total_cases': 55023.0,
#    'new_cases': 15.0,
#    'new_cases_smoothed': 61.143,
#    'total_deaths': 2400.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 3.143,
#    'total_cases_per_million': 1413.443,
#    'new_cases_per_million': 0.385,
#    'new_cases_smoothed_per_million': 1.571,
#    'total_deaths_per_million': 61.652,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.081,
#    'reproduction_rate': 0.68,
#    'stringency_index': 12.04},
#   {'date': '2021-02-01',
#    'total_cases': 55059.0,
#    'new_cases': 36.0,
#    'new_cases_smoothed': 55.286,
#    'total_deaths': 2404.0,
#    'new_deaths': 4.0,
#    'new_deaths_smoothed': 2.714,
#    'total_cases_per_million': 1414.368,
#    'new_cases_per_million': 0.925,
#    'new_cases_smoothed_per_million': 1.42,
#    'total_deaths_per_million': 61.754,
#    'new_deaths_per_million': 0.103,
#    'new_deaths_smoothed_per_million': 0.07,
#    'reproduction_rate': 0.68,
#    'stringency_index': 12.04},
#   {'date': '2021-02-02',
#    'total_cases': 55121.0,
#    'new_cases': 62.0,
#    'new_cases_smoothed': 53.0,
#    'total_deaths': 2405.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 2.286,
#    'total_cases_per_million': 1415.961,
#    'new_cases_per_million': 1.593,
#    'new_cases_smoothed_per_million': 1.361,
#    'total_deaths_per_million': 61.78,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.059,
#    'reproduction_rate': 0.69,
#    'stringency_index': 12.04},
#   {'date': '2021-02-03',
#    'total_cases': 55174.0,
#    'new_cases': 53.0,
#    'new_cases_smoothed': 45.714,
#    'total_deaths': 2406.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 2.429,
#    'total_cases_per_million': 1417.322,
#    'new_cases_per_million': 1.361,
#    'new_cases_smoothed_per_million': 1.174,
#    'total_deaths_per_million': 61.806,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.062,
#    'reproduction_rate': 0.68,
#    'stringency_index': 12.04},
#   {'date': '2021-02-04',
#    'total_cases': 55231.0,
#    'new_cases': 57.0,
#    'new_cases_smoothed': 48.571,
#    'total_deaths': 2407.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.429,
#    'total_cases_per_million': 1418.786,
#    'new_cases_per_million': 1.464,
#    'new_cases_smoothed_per_million': 1.248,
#    'total_deaths_per_million': 61.832,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.037,
#    'reproduction_rate': 0.68,
#    'stringency_index': 12.04},
#   {'date': '2021-02-05',
#    'total_cases': 55265.0,
#    'new_cases': 34.0,
#    'new_cases_smoothed': 46.571,
#    'total_deaths': 2407.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 1.143,
#    'total_cases_per_million': 1419.66,
#    'new_cases_per_million': 0.873,
#    'new_cases_smoothed_per_million': 1.196,
#    'total_deaths_per_million': 61.832,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.029,
#    'reproduction_rate': 0.66,
#    'stringency_index': 12.04},
#   {'date': '2021-02-06',
#    'total_cases': 55330.0,
#    'new_cases': 65.0,
#    'new_cases_smoothed': 46.0,
#    'total_deaths': 2408.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.143,
#    'total_cases_per_million': 1421.33,
#    'new_cases_per_million': 1.67,
#    'new_cases_smoothed_per_million': 1.182,
#    'total_deaths_per_million': 61.857,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.029,
#    'reproduction_rate': 0.65,
#    'stringency_index': 12.04},
#   {'date': '2021-02-07',
#    'total_cases': 55335.0,
#    'new_cases': 5.0,
#    'new_cases_smoothed': 44.571,
#    'total_deaths': 2410.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 1.429,
#    'total_cases_per_million': 1421.458,
#    'new_cases_per_million': 0.128,
#    'new_cases_smoothed_per_million': 1.145,
#    'total_deaths_per_million': 61.909,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.037,
#    'reproduction_rate': 0.63,
#    'stringency_index': 12.04},
#   {'date': '2021-02-08',
#    'total_cases': 55359.0,
#    'new_cases': 24.0,
#    'new_cases_smoothed': 42.857,
#    'total_deaths': 2413.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 1.286,
#    'total_cases_per_million': 1422.074,
#    'new_cases_per_million': 0.617,
#    'new_cases_smoothed_per_million': 1.101,
#    'total_deaths_per_million': 61.986,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.033,
#    'reproduction_rate': 0.63,
#    'stringency_index': 12.04},
#   {'date': '2021-02-09',
#    'total_cases': 55384.0,
#    'new_cases': 25.0,
#    'new_cases_smoothed': 37.571,
#    'total_deaths': 2414.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.286,
#    'total_cases_per_million': 1422.717,
#    'new_cases_per_million': 0.642,
#    'new_cases_smoothed_per_million': 0.965,
#    'total_deaths_per_million': 62.011,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.033,
#    'reproduction_rate': 0.62,
#    'stringency_index': 12.04},
#   {'date': '2021-02-10',
#    'total_cases': 55402.0,
#    'new_cases': 18.0,
#    'new_cases_smoothed': 32.571,
#    'total_deaths': 2418.0,
#    'new_deaths': 4.0,
#    'new_deaths_smoothed': 1.714,
#    'total_cases_per_million': 1423.179,
#    'new_cases_per_million': 0.462,
#    'new_cases_smoothed_per_million': 0.837,
#    'total_deaths_per_million': 62.114,
#    'new_deaths_per_million': 0.103,
#    'new_deaths_smoothed_per_million': 0.044,
#    'reproduction_rate': 0.62},
#   {'date': '2021-02-11',
#    'total_cases': 55420.0,
#    'new_cases': 18.0,
#    'new_cases_smoothed': 27.0,
#    'total_deaths': 2419.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 1.714,
#    'total_cases_per_million': 1423.641,
#    'new_cases_per_million': 0.462,
#    'new_cases_smoothed_per_million': 0.694,
#    'total_deaths_per_million': 62.14,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.044,
#    'reproduction_rate': 0.62},
#   {'date': '2021-02-12',
#    'total_cases': 55445.0,
#    'new_cases': 25.0,
#    'new_cases_smoothed': 25.714,
#    'total_deaths': 2424.0,
#    'new_deaths': 5.0,
#    'new_deaths_smoothed': 2.429,
#    'total_cases_per_million': 1424.284,
#    'new_cases_per_million': 0.642,
#    'new_cases_smoothed_per_million': 0.661,
#    'total_deaths_per_million': 62.268,
#    'new_deaths_per_million': 0.128,
#    'new_deaths_smoothed_per_million': 0.062,
#    'reproduction_rate': 0.62},
#   {'date': '2021-02-13',
#    'total_cases': 55473.0,
#    'new_cases': 28.0,
#    'new_cases_smoothed': 20.429,
#    'total_deaths': 2427.0,
#    'new_deaths': 3.0,
#    'new_deaths_smoothed': 2.714,
#    'total_cases_per_million': 1425.003,
#    'new_cases_per_million': 0.719,
#    'new_cases_smoothed_per_million': 0.525,
#    'total_deaths_per_million': 62.345,
#    'new_deaths_per_million': 0.077,
#    'new_deaths_smoothed_per_million': 0.07,
#    'reproduction_rate': 0.62},
#   {'date': '2021-02-14',
#    'total_cases': 55492.0,
#    'new_cases': 19.0,
#    'new_cases_smoothed': 22.429,
#    'total_deaths': 2427.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 2.429,
#    'total_cases_per_million': 1425.491,
#    'new_cases_per_million': 0.488,
#    'new_cases_smoothed_per_million': 0.576,
#    'total_deaths_per_million': 62.345,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.062,
#    'reproduction_rate': 0.62},
#   {'date': '2021-02-15',
#    'total_cases': 55514.0,
#    'new_cases': 22.0,
#    'new_cases_smoothed': 22.143,
#    'total_deaths': 2427.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 2.0,
#    'total_cases_per_million': 1426.056,
#    'new_cases_per_million': 0.565,
#    'new_cases_smoothed_per_million': 0.569,
#    'total_deaths_per_million': 62.345,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.051,
#    'reproduction_rate': 0.62},
#   {'date': '2021-02-16',
#    'total_cases': 55518.0,
#    'new_cases': 4.0,
#    'new_cases_smoothed': 19.143,
#    'total_deaths': 2428.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 2.0,
#    'total_cases_per_million': 1426.159,
#    'new_cases_per_million': 0.103,
#    'new_cases_smoothed_per_million': 0.492,
#    'total_deaths_per_million': 62.371,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.051,
#    'reproduction_rate': 0.62},
#   {'date': '2021-02-17',
#    'total_cases': 55540.0,
#    'new_cases': 22.0,
#    'new_cases_smoothed': 19.714,
#    'total_deaths': 2428.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 1.429,
#    'total_cases_per_million': 1426.724,
#    'new_cases_per_million': 0.565,
#    'new_cases_smoothed_per_million': 0.506,
#    'total_deaths_per_million': 62.371,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.037,
#    'reproduction_rate': 0.63},
#   {'date': '2021-02-18',
#    'total_cases': 55557.0,
#    'new_cases': 17.0,
#    'new_cases_smoothed': 19.571,
#    'total_deaths': 2430.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 1.571,
#    'total_cases_per_million': 1427.161,
#    'new_cases_per_million': 0.437,
#    'new_cases_smoothed_per_million': 0.503,
#    'total_deaths_per_million': 62.422,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.04,
#    'reproduction_rate': 0.63},
#   {'date': '2021-02-19',
#    'total_cases': 55575.0,
#    'new_cases': 18.0,
#    'new_cases_smoothed': 18.571,
#    'total_deaths': 2430.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.857,
#    'total_cases_per_million': 1427.623,
#    'new_cases_per_million': 0.462,
#    'new_cases_smoothed_per_million': 0.477,
#    'total_deaths_per_million': 62.422,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.022,
#    'reproduction_rate': 0.63},
#   {'date': '2021-02-20',
#    'total_cases': 55580.0,
#    'new_cases': 5.0,
#    'new_cases_smoothed': 15.286,
#    'total_deaths': 2430.0,
#    'new_deaths': 0.0,
#    'new_deaths_smoothed': 0.429,
#    'total_cases_per_million': 1427.752,
#    'new_cases_per_million': 0.128,
#    'new_cases_smoothed_per_million': 0.393,
#    'total_deaths_per_million': 62.422,
#    'new_deaths_per_million': 0.0,
#    'new_deaths_smoothed_per_million': 0.011,
#    'reproduction_rate': 0.63},
#   {'date': '2021-02-21',
#    'total_cases': 55604.0,
#    'new_cases': 24.0,
#    'new_cases_smoothed': 16.0,
#    'total_deaths': 2432.0,
#    'new_deaths': 2.0,
#    'new_deaths_smoothed': 0.714,
#    'total_cases_per_million': 1428.368,
#    'new_cases_per_million': 0.617,
#    'new_cases_smoothed_per_million': 0.411,
#    'total_deaths_per_million': 62.474,
#    'new_deaths_per_million': 0.051,
#    'new_deaths_smoothed_per_million': 0.018,
#    'reproduction_rate': 0.64},
#   {'date': '2021-02-22',
#    'total_cases': 55617.0,
#    'new_cases': 13.0,
#    'new_cases_smoothed': 14.714,
#    'total_deaths': 2433.0,
#    'new_deaths': 1.0,
#    'new_deaths_smoothed': 0.857,
#    'total_cases_per_million': 1428.702,
#    'new_cases_per_million': 0.334,
#    'new_cases_smoothed_per_million': 0.378,
#    'total_deaths_per_million': 62.499,
#    'new_deaths_per_million': 0.026,
#    'new_deaths_smoothed_per_million': 0.022}]}

# %% [markdown]
# Load data into a pandas DataFrame

# %%
# load data into a pandas DataFrame
covid_json_df = pd.read_json(covid_path)
display(covid_json_df)
# Out:
#                                                                           AFG  \
# continent                                                                Asia
# location                                                          Afghanistan
# population                                                        3.89283e+07
# population_density                                                     54.422
# median_age                                                               18.6
# aged_65_older                                                           2.581
# aged_70_older                                                           1.337
# gdp_per_capita                                                        1803.99
# cardiovasc_death_rate                                                 597.029
# diabetes_prevalence                                                      9.59
# handwashing_facilities                                                 37.746
# hospital_beds_per_thousand                                                0.5
# life_expectancy                                                         64.83
# human_development_index                                                 0.511
# data                        [{'date': '2020-02-24', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                            NaN
# male_smokers                                                              NaN
#
#                                                                      OWID_AFR  \
# continent                                                                 NaN
# location                                                               Africa
# population                                                         1.3406e+09
# population_density                                                        NaN
# median_age                                                                NaN
# aged_65_older                                                             NaN
# aged_70_older                                                             NaN
# gdp_per_capita                                                            NaN
# cardiovasc_death_rate                                                     NaN
# diabetes_prevalence                                                       NaN
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                NaN
# life_expectancy                                                           NaN
# human_development_index                                                   NaN
# data                        [{'date': '2020-02-13', 'new_cases': 0.0, 'new...
# extreme_poverty                                                           NaN
# female_smokers                                                            NaN
# male_smokers                                                              NaN
#
#                                                                           ALB  \
# continent                                                              Europe
# location                                                              Albania
# population                                                         2.8778e+06
# population_density                                                    104.871
# median_age                                                                 38
# aged_65_older                                                          13.188
# aged_70_older                                                           8.643
# gdp_per_capita                                                        11803.4
# cardiovasc_death_rate                                                 304.195
# diabetes_prevalence                                                     10.08
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                               2.89
# life_expectancy                                                         78.57
# human_development_index                                                 0.795
# data                        [{'date': '2020-02-25', 'new_tests': 8.0, 'tot...
# extreme_poverty                                                           1.1
# female_smokers                                                            7.1
# male_smokers                                                             51.2
#
#                                                                           DZA  \
# continent                                                              Africa
# location                                                              Algeria
# population                                                         4.3851e+07
# population_density                                                     17.348
# median_age                                                               29.1
# aged_65_older                                                           6.211
# aged_70_older                                                           3.857
# gdp_per_capita                                                        13913.8
# cardiovasc_death_rate                                                 278.364
# diabetes_prevalence                                                      6.73
# handwashing_facilities                                                 83.741
# hospital_beds_per_thousand                                                1.9
# life_expectancy                                                         76.88
# human_development_index                                                 0.748
# data                        [{'date': '2020-02-25', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           0.5
# female_smokers                                                            0.7
# male_smokers                                                             30.4
#
#                                                                           AND  \
# continent                                                              Europe
# location                                                              Andorra
# population                                                              77265
# population_density                                                    163.755
# median_age                                                                NaN
# aged_65_older                                                             NaN
# aged_70_older                                                             NaN
# gdp_per_capita                                                            NaN
# cardiovasc_death_rate                                                 109.135
# diabetes_prevalence                                                      7.97
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                NaN
# life_expectancy                                                         83.73
# human_development_index                                                 0.868
# data                        [{'date': '2020-03-02', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                             29
# male_smokers                                                             37.8
#
#                                                                           AGO  \
# continent                                                              Africa
# location                                                               Angola
# population                                                        3.28663e+07
# population_density                                                      23.89
# median_age                                                               16.8
# aged_65_older                                                           2.405
# aged_70_older                                                           1.362
# gdp_per_capita                                                        5819.49
# cardiovasc_death_rate                                                 276.045
# diabetes_prevalence                                                      3.94
# handwashing_facilities                                                 26.664
# hospital_beds_per_thousand                                                NaN
# life_expectancy                                                         61.15
# human_development_index                                                 0.581
# data                        [{'date': '2020-03-20', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                            NaN
# male_smokers                                                              NaN
#
#                                                                           AIA  \
# continent                                                       North America
# location                                                             Anguilla
# population                                                              15002
# population_density                                                        NaN
# median_age                                                                NaN
# aged_65_older                                                             NaN
# aged_70_older                                                             NaN
# gdp_per_capita                                                            NaN
# cardiovasc_death_rate                                                     NaN
# diabetes_prevalence                                                       NaN
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                NaN
# life_expectancy                                                         81.88
# human_development_index                                                   NaN
# data                        [{'date': '2021-02-04', 'total_vaccinations': ...
# extreme_poverty                                                           NaN
# female_smokers                                                            NaN
# male_smokers                                                              NaN
#
#                                                                           ATG  \
# continent                                                       North America
# location                                                  Antigua and Barbuda
# population                                                              97928
# population_density                                                    231.845
# median_age                                                               32.1
# aged_65_older                                                           6.933
# aged_70_older                                                           4.631
# gdp_per_capita                                                        21490.9
# cardiovasc_death_rate                                                 191.511
# diabetes_prevalence                                                     13.17
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                3.8
# life_expectancy                                                         77.02
# human_development_index                                                 0.778
# data                        [{'date': '2020-03-13', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                            NaN
# male_smokers                                                              NaN
#
#                                                                           ARG  \
# continent                                                       South America
# location                                                            Argentina
# population                                                        4.51958e+07
# population_density                                                     16.177
# median_age                                                               31.9
# aged_65_older                                                          11.198
# aged_70_older                                                           7.441
# gdp_per_capita                                                        18933.9
# cardiovasc_death_rate                                                 191.032
# diabetes_prevalence                                                       5.5
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                  5
# life_expectancy                                                         76.67
# human_development_index                                                 0.845
# data                        [{'date': '2020-01-01', 'new_tests': 4.0, 'tot...
# extreme_poverty                                                           0.6
# female_smokers                                                           16.2
# male_smokers                                                             27.7
#
#                                                                           ARM  \
# continent                                                                Asia
# location                                                              Armenia
# population                                                        2.96323e+06
# population_density                                                    102.931
# median_age                                                               35.7
# aged_65_older                                                          11.232
# aged_70_older                                                           7.571
# gdp_per_capita                                                        8787.58
# cardiovasc_death_rate                                                  341.01
# diabetes_prevalence                                                      7.11
# handwashing_facilities                                                 94.043
# hospital_beds_per_thousand                                                4.2
# life_expectancy                                                         75.09
# human_development_index                                                 0.776
# data                        [{'date': '2020-03-01', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           1.8
# female_smokers                                                            1.5
# male_smokers                                                             52.1
#
#                             ...  \
# continent                   ...
# location                    ...
# population                  ...
# population_density          ...
# median_age                  ...
# aged_65_older               ...
# aged_70_older               ...
# gdp_per_capita              ...
# cardiovasc_death_rate       ...
# diabetes_prevalence         ...
# handwashing_facilities      ...
# hospital_beds_per_thousand  ...
# life_expectancy             ...
# human_development_index     ...
# data                        ...
# extreme_poverty             ...
# female_smokers              ...
# male_smokers                ...
#
#                                                                           URY  \
# continent                                                       South America
# location                                                              Uruguay
# population                                                        3.47373e+06
# population_density                                                     19.751
# median_age                                                               35.6
# aged_65_older                                                          14.655
# aged_70_older                                                          10.361
# gdp_per_capita                                                        20551.4
# cardiovasc_death_rate                                                 160.708
# diabetes_prevalence                                                      6.93
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                2.8
# life_expectancy                                                         77.91
# human_development_index                                                 0.817
# data                        [{'date': '2020-03-13', 'total_cases': 4.0, 'n...
# extreme_poverty                                                           0.1
# female_smokers                                                             14
# male_smokers                                                             19.9
#
#                                                                           UZB  \
# continent                                                                Asia
# location                                                           Uzbekistan
# population                                                        3.34692e+07
# population_density                                                     76.134
# median_age                                                               28.2
# aged_65_older                                                           4.469
# aged_70_older                                                           2.873
# gdp_per_capita                                                         6253.1
# cardiovasc_death_rate                                                 724.417
# diabetes_prevalence                                                      7.57
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                  4
# life_expectancy                                                         71.72
# human_development_index                                                  0.72
# data                        [{'date': '2020-03-15', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                            1.3
# male_smokers                                                             24.7
#
#                                                                           VUT  \
# continent                                                             Oceania
# location                                                              Vanuatu
# population                                                             307150
# population_density                                                     22.662
# median_age                                                               23.1
# aged_65_older                                                           4.394
# aged_70_older                                                            2.62
# gdp_per_capita                                                        2921.91
# cardiovasc_death_rate                                                   546.3
# diabetes_prevalence                                                     12.02
# handwashing_facilities                                                 25.209
# hospital_beds_per_thousand                                                NaN
# life_expectancy                                                         70.47
# human_development_index                                                 0.609
# data                        [{'date': '2020-11-10', 'total_cases': 1.0, 'n...
# extreme_poverty                                                          13.2
# female_smokers                                                            2.8
# male_smokers                                                             34.5
#
#                                                                           VAT  \
# continent                                                              Europe
# location                                                              Vatican
# population                                                                809
# population_density                                                        NaN
# median_age                                                                NaN
# aged_65_older                                                             NaN
# aged_70_older                                                             NaN
# gdp_per_capita                                                            NaN
# cardiovasc_death_rate                                                     NaN
# diabetes_prevalence                                                       NaN
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                NaN
# life_expectancy                                                         75.12
# human_development_index                                                   NaN
# data                        [{'date': '2020-03-06', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                            NaN
# male_smokers                                                              NaN
#
#                                                                           VEN  \
# continent                                                       South America
# location                                                            Venezuela
# population                                                        2.84359e+07
# population_density                                                     36.253
# median_age                                                                 29
# aged_65_older                                                           6.614
# aged_70_older                                                           3.915
# gdp_per_capita                                                          16745
# cardiovasc_death_rate                                                  204.85
# diabetes_prevalence                                                      6.47
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                0.8
# life_expectancy                                                         72.06
# human_development_index                                                 0.711
# data                        [{'date': '2020-03-14', 'total_cases': 2.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                            NaN
# male_smokers                                                              NaN
#
#                                                                           VNM  \
# continent                                                                Asia
# location                                                              Vietnam
# population                                                        9.73386e+07
# population_density                                                    308.127
# median_age                                                               32.6
# aged_65_older                                                            7.15
# aged_70_older                                                           4.718
# gdp_per_capita                                                        6171.88
# cardiovasc_death_rate                                                 245.465
# diabetes_prevalence                                                         6
# handwashing_facilities                                                 85.847
# hospital_beds_per_thousand                                                2.6
# life_expectancy                                                          75.4
# human_development_index                                                 0.704
# data                        [{'date': '2020-01-23', 'total_cases': 2.0, 'n...
# extreme_poverty                                                             2
# female_smokers                                                              1
# male_smokers                                                             45.9
#
#                                                                      OWID_WRL  \
# continent                                                                 NaN
# location                                                                World
# population                                                         7.7948e+09
# population_density                                                     58.045
# median_age                                                               30.9
# aged_65_older                                                           8.696
# aged_70_older                                                           5.355
# gdp_per_capita                                                        15469.2
# cardiovasc_death_rate                                                  233.07
# diabetes_prevalence                                                      8.51
# handwashing_facilities                                                  60.13
# hospital_beds_per_thousand                                              2.705
# life_expectancy                                                         72.58
# human_development_index                                                 0.737
# data                        [{'date': '2020-01-22', 'total_cases': 557.0, ...
# extreme_poverty                                                            10
# female_smokers                                                          6.434
# male_smokers                                                           34.635
#
#                                                                           YEM  \
# continent                                                                Asia
# location                                                                Yemen
# population                                                         2.9826e+07
# population_density                                                     53.508
# median_age                                                               20.3
# aged_65_older                                                           2.922
# aged_70_older                                                           1.583
# gdp_per_capita                                                        1479.15
# cardiovasc_death_rate                                                 495.003
# diabetes_prevalence                                                      5.35
# handwashing_facilities                                                 49.542
# hospital_beds_per_thousand                                                0.7
# life_expectancy                                                         66.12
# human_development_index                                                  0.47
# data                        [{'date': '2020-04-10', 'total_cases': 1.0, 'n...
# extreme_poverty                                                          18.8
# female_smokers                                                            7.6
# male_smokers                                                             29.2
#
#                                                                           ZMB  \
# continent                                                              Africa
# location                                                               Zambia
# population                                                         1.8384e+07
# population_density                                                     22.995
# median_age                                                               17.7
# aged_65_older                                                            2.48
# aged_70_older                                                           1.542
# gdp_per_capita                                                        3689.25
# cardiovasc_death_rate                                                 234.499
# diabetes_prevalence                                                      3.94
# handwashing_facilities                                                 13.938
# hospital_beds_per_thousand                                                  2
# life_expectancy                                                         63.89
# human_development_index                                                 0.584
# data                        [{'date': '2020-03-18', 'total_cases': 2.0, 'n...
# extreme_poverty                                                          57.5
# female_smokers                                                            3.1
# male_smokers                                                             24.7
#
#                                                                           ZWE
# continent                                                              Africa
# location                                                             Zimbabwe
# population                                                        1.48629e+07
# population_density                                                     42.729
# median_age                                                               19.6
# aged_65_older                                                           2.822
# aged_70_older                                                           1.882
# gdp_per_capita                                                        1899.78
# cardiovasc_death_rate                                                 307.846
# diabetes_prevalence                                                      1.82
# handwashing_facilities                                                 36.791
# hospital_beds_per_thousand                                                1.7
# life_expectancy                                                         61.49
# human_development_index                                                 0.571
# data                        [{'date': '2020-03-20', 'total_cases': 1.0, 'n...
# extreme_poverty                                                          21.4
# female_smokers                                                            1.6
# male_smokers                                                             30.7
#
# [18 rows x 214 columns]

# %% [markdown]
# Let's traspose the DataFrame so each country corresponds to a case and the attributes (measures) are located as columns

# %%
covid_json_T = pd.DataFrame(covid_json).T
display(covid_json_T.head())
# Out:
#          continent     location   population population_density median_age  \
# AFG           Asia  Afghanistan  3.89283e+07             54.422       18.6
# OWID_AFR       NaN       Africa   1.3406e+09                NaN        NaN
# ALB         Europe      Albania   2.8778e+06            104.871         38
# DZA         Africa      Algeria   4.3851e+07             17.348       29.1
# AND         Europe      Andorra        77265            163.755        NaN
#
#          aged_65_older aged_70_older gdp_per_capita cardiovasc_death_rate  \
# AFG              2.581         1.337        1803.99               597.029
# OWID_AFR           NaN           NaN            NaN                   NaN
# ALB             13.188         8.643        11803.4               304.195
# DZA              6.211         3.857        13913.8               278.364
# AND                NaN           NaN            NaN               109.135
#
#          diabetes_prevalence handwashing_facilities  \
# AFG                     9.59                 37.746
# OWID_AFR                 NaN                    NaN
# ALB                    10.08                    NaN
# DZA                     6.73                 83.741
# AND                     7.97                    NaN
#
#          hospital_beds_per_thousand life_expectancy human_development_index  \
# AFG                             0.5           64.83                   0.511
# OWID_AFR                        NaN             NaN                     NaN
# ALB                            2.89           78.57                   0.795
# DZA                             1.9           76.88                   0.748
# AND                             NaN           83.73                   0.868
#
#                                                        data extreme_poverty  \
# AFG       [{'date': '2020-02-24', 'total_cases': 1.0, 'n...             NaN
# OWID_AFR  [{'date': '2020-02-13', 'new_cases': 0.0, 'new...             NaN
# ALB       [{'date': '2020-02-25', 'new_tests': 8.0, 'tot...             1.1
# DZA       [{'date': '2020-02-25', 'total_cases': 1.0, 'n...             0.5
# AND       [{'date': '2020-03-02', 'total_cases': 1.0, 'n...             NaN
#
#          female_smokers male_smokers
# AFG                 NaN          NaN
# OWID_AFR            NaN          NaN
# ALB                 7.1         51.2
# DZA                 0.7         30.4
# AND                  29         37.8

# %% [markdown]
# Now, let's flatten the information inside data. We are going to create a function to iterate through a list of countries ISO codes and append all that information into a single DataFrame. We are going to use the original JSON file loaded, as json_normalize() only takes a dictionary or list of dictionaries.

# %%
# list of countries to extract data from
countries = ['ESP', 'ISR', 'GBR']

def flatten_by_countries(list_countries):
    # empty list to store dfs
    covid_sel_countries = []
    
    for country in list_countries:
        # we only select 'location' as the only metadata that we want
        # to extract, for now
        covid_json_df_flatten = json_normalize(covid_json[country],
                                               record_path='data',
                                               meta=['location'])
        
        covid_sel_countries.append(covid_json_df_flatten)
        
    # concatenate dfs
    dfs = pd.concat(covid_sel_countries)
    
    return dfs

# %% [markdown]
# We can see in the resulting DataFrame that we have data from Israel, Spain and the United Kingdom.

# %%
covid_sel_countries_df = flatten_by_countries(countries)
covid_sel_countries_df.groupby(['location']).first()
# Out:
# C:\Users\sebas\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   del sys.path[0]
#                       date  total_cases  new_cases  total_cases_per_million  \
# location
# Israel          2020-02-20          1.0        1.0                    0.116
# Spain           2020-02-01          1.0        1.0                    0.021
# United Kingdom  2020-01-31          2.0        2.0                    0.029
#
#                 new_cases_per_million  stringency_index  \
# location
# Israel                          0.116             19.44
# Spain                           0.021             11.11
# United Kingdom                  0.029              8.33
#
#                 weekly_icu_admissions  weekly_icu_admissions_per_million  \
# location
# Israel                          5.000                              0.578
# Spain                           2.963                              0.063
# United Kingdom                    NaN                                NaN
#
#                 weekly_hosp_admissions  weekly_hosp_admissions_per_million  \
# location
# Israel                          22.000                               2.542
# Spain                           18.768                               0.401
# United Kingdom               13915.000                             204.976
#
#                 ...  people_vaccinated  total_vaccinations_per_hundred  \
# location        ...
# Israel          ...               60.0                            0.00
# Spain           ...            82834.0                            0.18
# United Kingdom  ...            86265.0                            0.13
#
#                 people_vaccinated_per_hundred  new_vaccinations  \
# location
# Israel                                   0.00            7361.0
# Spain                                    0.18           56505.0
# United Kingdom                           0.13          165844.0
#
#                 new_vaccinations_smoothed  \
# location
# Israel                             7361.0
# Spain                             56505.0
# United Kingdom                    83999.0
#
#                 new_vaccinations_smoothed_per_million  \
# location
# Israel                                          850.0
# Spain                                          1209.0
# United Kingdom                                 1237.0
#
#                 people_fully_vaccinated  people_fully_vaccinated_per_hundred  \
# location
# Israel                              2.0                                 0.00
# Spain                            2315.0                                 0.00
# United Kingdom                  21919.0                                 0.03
#
#                 new_tests  new_tests_per_thousand
# location
# Israel               29.0                   0.003
# Spain                 NaN                     NaN
# United Kingdom    11896.0                   0.175
#
# [3 rows x 41 columns]

# %% [markdown]
# # Load data using an API connection

# %%
# load the api key stores in a txt file
api_key_path = 'G:/Mi unidad/GITHUB/data_science_projects/use_SQL_json_files/api_key.txt'

# load file
with open(api_key_path, 'r') as file:
    api_key = file.read().replace('\n', '')

# %% [markdown]
# Send request through the API

# %%
api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'pub',
          'location': 'Barcelona'}
headers = {'Authorization': 'Bearer {}'.format(api_key)}
# create_engine
response = requests.get(api_url,
                        params=params,
                        headers=headers)

# %%
# it only provides the first 20 results, we will have to change de params['offset'] = 20 to get the next 20 results
yelp_req = response.json()
yelp_req
# Out:
# {'businesses': [{'id': '0A7IoHQyqHo63kzJkTjwHw',
#    'alias': 'scobies-irish-pub-barcelona',
#    'name': 'Scobies Irish Pub',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Clw31quyQNRwVH5IqUIi8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scobies-irish-pub-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 24,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.3864229317709,
#     'longitude': 2.16614611194039},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Ronda de la Universidad, 8',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08007',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Ronda de la Universidad, 8',
#      '08007 Barcelona',
#      'Spain']},
#    'phone': '+34936011908',
#    'display_phone': '+34 936 01 19 08',
#    'distance': 591.0563407789787},
#   {'id': 'mkg0NJaGers9EmUx8GH7IQ',
#    'alias': 'the-michael-collins-barcelona',
#    'name': 'The Michael Collins',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BAFGr62OEE3qndq34OEScA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-michael-collins-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 40,
#    'categories': [{'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.40213, 'longitude': 2.17258},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Plaça de la Sagrada Família, 4',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08013',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Plaça de la Sagrada Família, 4',
#      '08013 Barcelona',
#      'Spain']},
#    'phone': '+34934591964',
#    'display_phone': '+34 934 59 19 64',
#    'distance': 1361.6170418893162},
#   {'id': 'lWrY2eON1BGbfP8nesPq_g',
#    'alias': 'flahertys-barcelona-9',
#    'name': "Flaherty's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aJTB9en_RrObOpTMp3nTOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flahertys-barcelona-9?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 38,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.3784405, 'longitude': 2.17677},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Plaça de Joaquim Xirau, s/n',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08002',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Plaça de Joaquim Xirau, s/n',
#      '08002 Barcelona',
#      'Spain']},
#    'phone': '+34934126263',
#    'display_phone': '+34 934 12 62 63',
#    'distance': 1801.0533525209544},
#   {'id': 'aqZzgXnb7ShziQ-g_mK2vQ',
#    'alias': 'bar-rubí-barcelona',
#    'name': 'Bar Rubí',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9gIs7dT0ZuSyqW09S0YHGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-rub%C3%AD-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 37,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.3846112288092,
#     'longitude': 2.18044281005859},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Carrer Banys Vells, 6',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08003',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer Banys Vells, 6', '08003 Barcelona', 'Spain']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1572.689631409504},
#   {'id': 'sJZC55Suc_0nKYLmM1lQiA',
#    'alias': 'hogans-australian-pub-barcelona',
#    'name': "Hogan's Australian Pub",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9SjJ8DaJ0XmO4mGLZlpwoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hogans-australian-pub-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 6,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.3814697, 'longitude': 2.17275},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'La Rambla, 81',
#     'address2': None,
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08001',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['La Rambla, 81', '08001 Barcelona', 'Spain']},
#    'phone': '+34602380587',
#    'display_phone': '+34 602 38 05 87',
#    'distance': 1330.7726337594179},
#   {'id': 'qldDKSUkLqdOypquAOq1gg',
#    'alias': 'madame-george-barcelona-2',
#    'name': 'Madame George',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oR7fLb-8BwDyAJlJawvcow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madame-george-barcelona-2?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 4,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.40206, 'longitude': 2.20104},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Carrer de Pujades, 179',
#     'address2': None,
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08005',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de Pujades, 179', '08005 Barcelona', 'Spain']},
#    'phone': '+34955005151',
#    'display_phone': '+34 955 00 51 51',
#    'distance': 3305.921999420917},
#   {'id': '6y74f1VQADWMzxTiIMEVlw',
#    'alias': 'dow-jones-barcelona-3',
#    'name': 'Dow Jones',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Rgykoy6hrRntL369PURHpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dow-jones-barcelona-3?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 46,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 41.3955399, 'longitude': 2.16773},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Carrer del Bruc, 97',
#     'address2': None,
#     'address3': None,
#     'city': 'Barcelona',
#     'zip_code': '08009',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer del Bruc, 97', '08009 Barcelona', 'Spain']},
#    'phone': '+34934763831',
#    'display_phone': '+34 934 76 38 31',
#    'distance': 535.1035602817286},
#   {'id': '_uG35jSXw79fSAW5Nupftg',
#    'alias': 'the-bollocks-barcelona',
#    'name': 'The Bollocks',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-JSH1-DBVH3ZRxTrberf8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bollocks-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 18,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.38103, 'longitude': 2.18045},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Carrer Ample, 46',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08002',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer Ample, 46', '08002 Barcelona', 'Spain']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1802.5245877862887},
#   {'id': 'x5iHnyigARDYdlDNKaL5zQ',
#    'alias': 'garage-beer-co-barcelona-2',
#    'name': 'Garage Beer Co',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mseL9FaJzt-FDZzTej0DPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garage-beer-co-barcelona-2?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 42,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.3870099, 'longitude': 2.16012},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Carrer de Consell de Cent, 261',
#     'address2': None,
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08011',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de Consell de Cent, 261',
#      '08011 Barcelona',
#      'Spain']},
#    'phone': '+34935285989',
#    'display_phone': '+34 935 28 59 89',
#    'distance': 587.4096945202397},
#   {'id': 'THBKTsa-6WM5bf34hwhj5Q',
#    'alias': 'l-ovella-negra-barcelona',
#    'name': "L'Ovella Negra",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s7JvICxG6heYvZ2uLxpsjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-ovella-negra-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 80,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.38446, 'longitude': 2.1696},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Carrer de les Sitges, 5',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08001',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de les Sitges, 5',
#      '08001 Barcelona',
#      'Spain']},
#    'phone': '+34933171087',
#    'display_phone': '+34 933 17 10 87',
#    'distance': 910.8197344560962},
#   {'id': 'PW00T1kLy-iSkQjHb7K97w',
#    'alias': 'the-philharmonic-barcelona',
#    'name': 'The Philharmonic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tdFJTgNw2MtKNbt4cjy3TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-philharmonic-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 14,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.39041, 'longitude': 2.15819},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Carrer de Mallorca, 204',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08036',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de Mallorca, 204',
#      '08036 Barcelona',
#      'Spain']},
#    'phone': '+34934515043',
#    'display_phone': '+34 934 51 50 43',
#    'distance': 497.3420580526616},
#   {'id': 'A5ybB2ZKQqyBz1pe2_OXSg',
#    'alias': 'chill-bar-barcelona',
#    'name': 'Chill Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/boDjKmuK-yusWuGvRCl7rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chill-bar-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 139,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.4024951623078,
#     'longitude': 2.17181160881923},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Carrer Provença, 424',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08025',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer Provença, 424', '08025 Barcelona', 'Spain']},
#    'phone': '+34934762270',
#    'display_phone': '+34 934 76 22 70',
#    'distance': 1388.810846216694},
#   {'id': 'aoNx2VWvEISIqGtLSab0aQ',
#    'alias': 'nevermind-barcelona-3',
#    'name': 'Nevermind',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XqToo_Cxd6feRSnLy3I7aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nevermind-barcelona-3?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 15,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.385077, 'longitude': 2.166406},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Carrer dels Tallers, 68',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08001',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer dels Tallers, 68',
#      '08001 Barcelona',
#      'Spain']},
#    'phone': '+34663710095',
#    'display_phone': '+34 663 71 00 95',
#    'distance': 740.5559122742777},
#   {'id': 'Atm_x8BUy7LMW3JzfoDZtw',
#    'alias': 'bobbys-free-barcelona',
#    'name': "Bobby's Free",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/81514OCoUwfoIAmoZ0rr_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bobbys-free-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 21,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.389868, 'longitude': 2.170668},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Carrer de Pau Claris, 85',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08010',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de Pau Claris, 85',
#      '08010 Barcelona',
#      'Spain']},
#    'phone': '+34932779773',
#    'display_phone': '+34 932 77 97 73',
#    'distance': 587.3239083545865},
#   {'id': 'NzCg_a3EfmoC4QC3FTO7Zw',
#    'alias': 'hemingway-barcelona-2',
#    'name': 'Hemingway',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/48jvgYUdd2Lh9nk65pRR0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hemingway-barcelona-2?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 18,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.38933, 'longitude': 2.15599},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Carrer de Muntaner, 114',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08036',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de Muntaner, 114',
#      '08036 Barcelona',
#      'Spain']},
#    'phone': '+34931296793',
#    'display_phone': '+34 931 29 67 93',
#    'distance': 694.4882047337445},
#   {'id': 'Eqww4YG3gYXC-d8kdcgXDw',
#    'alias': 'old-fashioned-barcelona',
#    'name': 'Old Fashioned',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Bb1c0Z1wh09tWokrSHNwtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-fashioned-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 107,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.398016, 'longitude': 2.159741},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Carrer de Santa Teresa, 1',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08012',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de Santa Teresa, 1',
#      '08012 Barcelona',
#      'Spain']},
#    'phone': '+34933685277',
#    'display_phone': '+34 933 68 52 77',
#    'distance': 807.6265249662584},
#   {'id': 'ireFL6RdLbg8zi0zd3JX5g',
#    'alias': 'h1898-rooftopbar-barcelona',
#    'name': 'H1898 Rooftopbar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PiwRve10PROVA8vOstMzww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/h1898-rooftopbar-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 7,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.3819808959961,
#     'longitude': 2.17480802536011},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Les Rambles, 109',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08002',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Les Rambles, 109', '08002 Barcelona', 'Spain']},
#    'phone': '+34935529552',
#    'display_phone': '+34 935 52 95 52',
#    'distance': 1076.3090629749058},
#   {'id': 'nAdaRb9mrqmT8bK7o0VNng',
#    'alias': 'never-more-barcelona',
#    'name': 'Never More',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MLI3x_gu5yjeDIpMIvbG8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/never-more-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 1,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'signature_cuisine', 'title': 'Signature Cuisine'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.3791244821836,
#     'longitude': 2.16651333529859},
#    'transactions': [],
#    'location': {'address1': 'Carrer de la Cera, 17',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08001',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de la Cera, 17', '08001 Barcelona', 'Spain']},
#    'phone': '+34932224696',
#    'display_phone': '+34 932 22 46 96',
#    'distance': 1390.2305757604001},
#   {'id': '4X49wdJcDGgMTVTXehH4tQ',
#    'alias': 'lunatic-barcelona',
#    'name': 'Lunatic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oavq9LgVXbAi8W0IFRzCKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lunatic-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 5,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'comedyclubs', 'title': 'Comedy Clubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.3774, 'longitude': 2.12351},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Carrer Regent Mendieta, 38',
#     'address2': None,
#     'address3': None,
#     'city': 'Barcelona',
#     'zip_code': '08028',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer Regent Mendieta, 38',
#      '08028 Barcelona',
#      'Spain']},
#    'phone': '+34933331172',
#    'display_phone': '+34 933 33 11 72',
#    'distance': 3720.4119978223007},
#   {'id': 'bS5eiWOZgjGmuN4OEyCuLw',
#    'alias': 'biercab-barcelona',
#    'name': 'Biercab',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rP2aE_umUTEnHfHxW-hkpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/biercab-barcelona?adjust_creative=Hhh9-Rd7Xt43fnI06s3biA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Hhh9-Rd7Xt43fnI06s3biA',
#    'review_count': 122,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.38621, 'longitude': 2.15978},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Carrer de Muntaner, 55',
#     'address2': '',
#     'address3': '',
#     'city': 'Barcelona',
#     'zip_code': '08011',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de Muntaner, 55', '08011 Barcelona', 'Spain']},
#    'phone': '+34644689045',
#    'display_phone': '+34 644 68 90 45',
#    'distance': 692.3712717461736}],
#  'total': 369,
#  'region': {'center': {'longitude': 2.1639633178710938,
#    'latitude': 41.391479886172114}}}

# %% [markdown]
# The data is stores inside the 'businesses' key in the JSON file, so let's flatten the file using json_normalize() and the original dictionary from the request.

# %%
yelp_req_df = pd.DataFrame(data_req['businesses'])
display(yelp_req_df.head())
# Out:
#                        id                            alias  \
# 0  0A7IoHQyqHo63kzJkTjwHw      scobies-irish-pub-barcelona
# 1  mkg0NJaGers9EmUx8GH7IQ    the-michael-collins-barcelona
# 2  lWrY2eON1BGbfP8nesPq_g            flahertys-barcelona-9
# 3  aqZzgXnb7ShziQ-g_mK2vQ               bar-rubí-barcelona
# 4  sJZC55Suc_0nKYLmM1lQiA  hogans-australian-pub-barcelona
#
#                      name                                          image_url  \
# 0       Scobies Irish Pub  https://s3-media3.fl.yelpcdn.com/bphoto/Clw31q...
# 1     The Michael Collins  https://s3-media4.fl.yelpcdn.com/bphoto/BAFGr6...
# 2              Flaherty's  https://s3-media2.fl.yelpcdn.com/bphoto/aJTB9e...
# 3                Bar Rubí  https://s3-media3.fl.yelpcdn.com/bphoto/9gIs7d...
# 4  Hogan's Australian Pub  https://s3-media1.fl.yelpcdn.com/bphoto/9SjJ8D...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/scobies-irish-pub-bar...            24
# 1      False  https://www.yelp.com/biz/the-michael-collins-b...            40
# 2      False  https://www.yelp.com/biz/flahertys-barcelona-9...            38
# 3      False  https://www.yelp.com/biz/bar-rub%C3%AD-barcelo...            37
# 4      False  https://www.yelp.com/biz/hogans-australian-pub...             6
#
#                                           categories  rating  \
# 0    [{'alias': 'irish_pubs', 'title': 'Irish Pub'}]     4.5
# 1    [{'alias': 'irish_pubs', 'title': 'Irish Pub'}]     4.0
# 2  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 3  [{'alias': 'spanish', 'title': 'Spanish'}, {'a...     4.5
# 4               [{'alias': 'pubs', 'title': 'Pubs'}]     4.0
#
#                                          coordinates transactions price  \
# 0  {'latitude': 41.3864229317709, 'longitude': 2....           []     €
# 1       {'latitude': 41.40213, 'longitude': 2.17258}           []    €€
# 2     {'latitude': 41.3784405, 'longitude': 2.17677}           []     €
# 3  {'latitude': 41.3846112288092, 'longitude': 2....           []     €
# 4     {'latitude': 41.3814697, 'longitude': 2.17275}           []    €€
#
#                                             location         phone  \
# 0  {'address1': 'Ronda de la Universidad, 8', 'ad...  +34936011908
# 1  {'address1': 'Plaça de la Sagrada Família, 4',...  +34934591964
# 2  {'address1': 'Plaça de Joaquim Xirau, s/n', 'a...  +34934126263
# 3  {'address1': 'Carrer Banys Vells, 6', 'address...
# 4  {'address1': 'La Rambla, 81', 'address2': None...  +34602380587
#
#       display_phone     distance
# 0  +34 936 01 19 08   591.056341
# 1  +34 934 59 19 64  1361.617042
# 2  +34 934 12 62 63  1801.053353
# 3                    1572.689631
# 4  +34 602 38 05 87  1330.772634

# %%
# json_normalize() takes a dictionary or list of dictionaries
yelp_df = json_normalize(yelp_req['businesses'],
                         record_path='categories',
                         sep='_',
                         meta=['name',
                               'is_closed',
                               'review_count',
                               'rating',
                               ['location', 'address1']],
                         meta_prefix='meta_')
# Out:
# C:\Users\sebas\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# This way we have flattened the data contained inside 'categories' = 'alias' and 'title'. We have also decided to load into the DataFrame metadata that is named using the prefix 'meta_'.

# %%
display(yelp_df.head())
# Out:
#         alias      title            meta_name meta_is_closed  \
# 0  irish_pubs  Irish Pub    Scobies Irish Pub          False
# 1  irish_pubs  Irish Pub  The Michael Collins          False
# 2     burgers    Burgers           Flaherty's          False
# 3  irish_pubs  Irish Pub           Flaherty's          False
# 4     spanish    Spanish             Bar Rubí          False
#
#   meta_review_count meta_rating          meta_location_address1
# 0                24         4.5      Ronda de la Universidad, 8
# 1                40           4  Plaça de la Sagrada Família, 4
# 2                38           4     Plaça de Joaquim Xirau, s/n
# 3                38           4     Plaça de Joaquim Xirau, s/n
# 4                37         4.5           Carrer Banys Vells, 6

# %% [markdown]
# # SQL

# %% [markdown]
# Now in this part of the notebook we are going to connect to PostgreSQL and request data from the DVDrental sample database, and practice some SQL queries.

# %%
# connect using SQLAlchemy
engine = create_engine('postgresql+psycopg2://postgres:#hd!Prmr1984cn@localhost/DVDrental')

# connect using psycopg2
conn_string = 'host=localhost dbname=DVDrental user=postgres password=#hd!Prmr1984cn'
conn = psycopg2.connect(conn_string)

# %%
# create a cursor object
cur = conn.cursor()
cur.execute("""SELECT * FROM actor;""")

# %%
# retrieve all from actor in tuples (inmutable objects of different type)
cur.fetchall()
# Out:
# [(1,
#   'Penelope',
#   'Guiness',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (2, 'Nick', 'Wahlberg', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (3, 'Ed', 'Chase', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (4, 'Jennifer', 'Davis', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (5,
#   'Johnny',
#   'Lollobrigida',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (6, 'Bette', 'Nicholson', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (7, 'Grace', 'Mostel', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (8,
#   'Matthew',
#   'Johansson',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (9, 'Joe', 'Swank', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (10,
#   'Christian',
#   'Gable',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (11, 'Zero', 'Cage', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (12, 'Karl', 'Berry', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (13, 'Uma', 'Wood', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (14, 'Vivien', 'Bergen', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (15, 'Cuba', 'Olivier', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (16, 'Fred', 'Costner', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (17, 'Helen', 'Voight', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (18, 'Dan', 'Torn', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (19, 'Bob', 'Fawcett', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (20, 'Lucille', 'Tracy', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (21,
#   'Kirsten',
#   'Paltrow',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (22, 'Elvis', 'Marx', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (23, 'Sandra', 'Kilmer', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (24, 'Cameron', 'Streep', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (25, 'Kevin', 'Bloom', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (26, 'Rip', 'Crawford', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (27, 'Julia', 'Mcqueen', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (28, 'Woody', 'Hoffman', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (29, 'Alec', 'Wayne', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (30, 'Sandra', 'Peck', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (31, 'Sissy', 'Sobieski', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (32, 'Tim', 'Hackman', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (33, 'Milla', 'Peck', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (34, 'Audrey', 'Olivier', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (35, 'Judy', 'Dean', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (36, 'Burt', 'Dukakis', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (37, 'Val', 'Bolger', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (38, 'Tom', 'Mckellen', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (39, 'Goldie', 'Brody', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (40, 'Johnny', 'Cage', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (41,
#   'Jodie',
#   'Degeneres',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (42, 'Tom', 'Miranda', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (43, 'Kirk', 'Jovovich', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (44, 'Nick', 'Stallone', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (45, 'Reese', 'Kilmer', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (46,
#   'Parker',
#   'Goldberg',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (47,
#   'Julia',
#   'Barrymore',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (48,
#   'Frances',
#   'Day-Lewis',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (49, 'Anne', 'Cronyn', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (50,
#   'Natalie',
#   'Hopkins',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (51, 'Gary', 'Phoenix', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (52, 'Carmen', 'Hunt', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (53, 'Mena', 'Temple', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (54,
#   'Penelope',
#   'Pinkett',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (55, 'Fay', 'Kilmer', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (56, 'Dan', 'Harris', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (57, 'Jude', 'Cruise', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (58,
#   'Christian',
#   'Akroyd',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (59, 'Dustin', 'Tautou', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (60, 'Henry', 'Berry', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (61,
#   'Christian',
#   'Neeson',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (62, 'Jayne', 'Neeson', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (63, 'Cameron', 'Wray', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (64, 'Ray', 'Johansson', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (65, 'Angela', 'Hudson', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (66, 'Mary', 'Tandy', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (67, 'Jessica', 'Bailey', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (68, 'Rip', 'Winslet', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (69,
#   'Kenneth',
#   'Paltrow',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (70,
#   'Michelle',
#   'Mcconaughey',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (71, 'Adam', 'Grant', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (72, 'Sean', 'Williams', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (73, 'Gary', 'Penn', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (74, 'Milla', 'Keitel', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (75, 'Burt', 'Posey', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (76,
#   'Angelina',
#   'Astaire',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (77,
#   'Cary',
#   'Mcconaughey',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (78,
#   'Groucho',
#   'Sinatra',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (79, 'Mae', 'Hoffman', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (80, 'Ralph', 'Cruz', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (81, 'Scarlett', 'Damon', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (82, 'Woody', 'Jolie', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (83, 'Ben', 'Willis', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (84, 'James', 'Pitt', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (85,
#   'Minnie',
#   'Zellweger',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (143, 'River', 'Dean', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (86, 'Greg', 'Chaplin', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (87, 'Spencer', 'Peck', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (88, 'Kenneth', 'Pesci', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (89, 'Charlize', 'Dench', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (90, 'Sean', 'Guiness', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (91,
#   'Christopher',
#   'Berry',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (92, 'Kirsten', 'Akroyd', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (93, 'Ellen', 'Presley', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (94, 'Kenneth', 'Torn', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (95, 'Daryl', 'Wahlberg', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (96, 'Gene', 'Willis', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (97, 'Meg', 'Hawke', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (98, 'Chris', 'Bridges', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (99, 'Jim', 'Mostel', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (100, 'Spencer', 'Depp', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (101, 'Susan', 'Davis', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (102, 'Walter', 'Torn', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (103, 'Matthew', 'Leigh', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (104,
#   'Penelope',
#   'Cronyn',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (105, 'Sidney', 'Crowe', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (106, 'Groucho', 'Dunst', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (107,
#   'Gina',
#   'Degeneres',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (108, 'Warren', 'Nolte', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (109,
#   'Sylvester',
#   'Dern',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (110, 'Susan', 'Davis', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (111,
#   'Cameron',
#   'Zellweger',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (112,
#   'Russell',
#   'Bacall',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (113,
#   'Morgan',
#   'Hopkins',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (114,
#   'Morgan',
#   'Mcdormand',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (115, 'Harrison', 'Bale', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (116, 'Dan', 'Streep', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (117, 'Renee', 'Tracy', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (118, 'Cuba', 'Allen', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (119,
#   'Warren',
#   'Jackman',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (120,
#   'Penelope',
#   'Monroe',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (121, 'Liza', 'Bergman', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (122, 'Salma', 'Nolte', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (123,
#   'Julianne',
#   'Dench',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (124,
#   'Scarlett',
#   'Bening',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (125, 'Albert', 'Nolte', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (126, 'Frances', 'Tomei', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (127, 'Kevin', 'Garland', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (128, 'Cate', 'Mcqueen', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (129,
#   'Daryl',
#   'Crawford',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (130, 'Greta', 'Keitel', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (131, 'Jane', 'Jackman', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (132, 'Adam', 'Hopper', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (133, 'Richard', 'Penn', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (134, 'Gene', 'Hopkins', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (135, 'Rita', 'Reynolds', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (136, 'Ed', 'Mansfield', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (137,
#   'Morgan',
#   'Williams',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (138, 'Lucille', 'Dee', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (139, 'Ewan', 'Gooding', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (140, 'Whoopi', 'Hurt', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (141, 'Cate', 'Harris', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (142, 'Jada', 'Ryder', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (144,
#   'Angela',
#   'Witherspoon',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (145, 'Kim', 'Allen', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (146,
#   'Albert',
#   'Johansson',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (147, 'Fay', 'Winslet', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (148, 'Emily', 'Dee', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (149,
#   'Russell',
#   'Temple',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (150, 'Jayne', 'Nolte', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (151,
#   'Geoffrey',
#   'Heston',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (152, 'Ben', 'Harris', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (153, 'Minnie', 'Kilmer', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (154, 'Meryl', 'Gibson', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (155, 'Ian', 'Tandy', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (156, 'Fay', 'Wood', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (157, 'Greta', 'Malden', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (158,
#   'Vivien',
#   'Basinger',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (159, 'Laura', 'Brody', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (160, 'Chris', 'Depp', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (161, 'Harvey', 'Hope', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (162, 'Oprah', 'Kilmer', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (163,
#   'Christopher',
#   'West',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (164,
#   'Humphrey',
#   'Willis',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (165, 'Al', 'Garland', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (166,
#   'Nick',
#   'Degeneres',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (167,
#   'Laurence',
#   'Bullock',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (168, 'Will', 'Wilson', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (169,
#   'Kenneth',
#   'Hoffman',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (170, 'Mena', 'Hopper', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (171,
#   'Olympia',
#   'Pfeiffer',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (172,
#   'Groucho',
#   'Williams',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (173, 'Alan', 'Dreyfuss', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (174,
#   'Michael',
#   'Bening',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (175,
#   'William',
#   'Hackman',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (176, 'Jon', 'Chase', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (177, 'Gene', 'Mckellen', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (178, 'Lisa', 'Monroe', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (179, 'Ed', 'Guiness', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (180,
#   'Jeff',
#   'Silverstone',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (181,
#   'Matthew',
#   'Carrey',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (182, 'Debbie', 'Akroyd', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (183, 'Russell', 'Close', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (184,
#   'Humphrey',
#   'Garland',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (185,
#   'Michael',
#   'Bolger',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (186,
#   'Julia',
#   'Zellweger',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (187, 'Renee', 'Ball', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (188, 'Rock', 'Dukakis', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (189, 'Cuba', 'Birch', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (190, 'Audrey', 'Bailey', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (191,
#   'Gregory',
#   'Gooding',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (192, 'John', 'Suvari', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (193, 'Burt', 'Temple', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (194, 'Meryl', 'Allen', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (195,
#   'Jayne',
#   'Silverstone',
#   datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (196, 'Bela', 'Walken', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (197, 'Reese', 'West', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (198, 'Mary', 'Keitel', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (199, 'Julia', 'Fawcett', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000)),
#  (200, 'Thora', 'Temple', datetime.datetime(2013, 5, 26, 14, 47, 57, 620000))]

# %% [markdown]
# Let's retrieve the tables names from the information_schema in the Database.

# %%
stmt = """SELECT table_name 
FROM information_schema.tables
WHERE table_schema = 'public'"""

cur.execute(stmt)
for table in cur.fetchall():
    print(table)
# Out:
# ('actor',)
# ('actor_info',)
# ('customer_list',)
# ('film_list',)
# ('nicer_but_slower_film_list',)
# ('sales_by_film_category',)
# ('store',)
# ('sales_by_store',)
# ('staff_list',)
# ('address',)
# ('category',)
# ('city',)
# ('country',)
# ('customer',)
# ('film_actor',)
# ('film_category',)
# ('inventory',)
# ('language',)
# ('rental',)
# ('staff',)
# ('payment',)
# ('film',)

# %%
stmt = """SELECT
    tc.table_schema, 
    tc.constraint_name, 
    tc.table_name, 
    kcu.column_name, 
    ccu.table_schema AS foreign_table_schema,
    ccu.table_name AS foreign_table_name,
    ccu.column_name AS foreign_column_name 
FROM 
    information_schema.table_constraints AS tc 
    JOIN information_schema.key_column_usage AS kcu
      ON tc.constraint_name = kcu.constraint_name
      AND tc.table_schema = kcu.table_schema
    JOIN information_schema.constraint_column_usage AS ccu
      ON ccu.constraint_name = tc.constraint_name
      AND ccu.table_schema = tc.table_schema
WHERE tc.constraint_type = 'FOREIGN KEY' AND tc.table_name='mytable';"""

cur.execute(stmt)
cur.fetchall()
# Out:
# []

# %% [markdown]
# ``` mysql
# SELECT title AS film_title
# FROM film
# INNER JOIN film_category
# USING(film_id)
# WHERE category_id=1
# ```

# %%
stmt = """SELECT title AS film_title 
FROM film 
INNER JOIN film_category 
USING(film_id) 
WHERE category_id=1;"""

pd.read_sql(stmt, conn)
# Out:
#                 film_title
# 0             Amadeus Holy
# 1          American Circus
# 2       Antitrust Tomatoes
# 3            Ark Ridgemont
# 4        Casualties Encino
# ..                     ...
# 59         Uprising Uptown
# 60  Waterfront Deliverance
# 61           Werewolf Lola
# 62            Women Dorado
# 63            Worst Banger
#
# [64 rows x 1 columns]

# %% [markdown]
# ``` mysql
# SELECT COUNT(*) AS films_number, name AS category
# FROM film
# INNER JOIN (
#     SELECT name, category_id, film_id
#     FROM category
#     INNER JOIN film_category
#     USING(category_id)) AS subquery
# USING(film_id)
# GROUP BY name
# ORDER BY films_number DESC;
# ```

# %%
# query
stmt = """SELECT name AS category, COUNT(*) AS n_films 
FROM film 
INNER JOIN (
    SELECT name, category_id, film_id 
    FROM category 
    INNER JOIN film_category 
    USING(category_id)) AS subquery 
USING(film_id) 
GROUP BY name 
ORDER BY n_films DESC;"""
# retrieve all from actor in a DataFrame
pd.read_sql(stmt, conn)
# Out:
#        category  n_films
# 0        Sports       74
# 1       Foreign       73
# 2        Family       69
# 3   Documentary       68
# 4     Animation       66
# 5        Action       64
# 6           New       63
# 7         Drama       62
# 8        Sci-Fi       61
# 9         Games       61
# 10     Children       60
# 11       Comedy       58
# 12       Travel       57
# 13     Classics       57
# 14       Horror       56
# 15        Music       51

# %% [markdown]
# ``` mysql
# SELECT title AS film_name, release_year, name AS category_name
# FROM film
# INNER JOIN (
#     SELECT name, film_id
#     FROM category
#     INNER JOIN film_category
#     USING(category_id)) AS subquery
# USING(film_id);
# ```

# %%
stmt = """SELECT title AS film_name, release_year, name AS category_name 
FROM film 
INNER JOIN (
    SELECT name, film_id 
    FROM category 
    INNER JOIN film_category 
    USING(category_id)) AS subquery 
USING(film_id);"""

pd.read_sql(stmt, conn)
# Out:
#              film_name  release_year category_name
# 0     Academy Dinosaur          2006   Documentary
# 1       Ace Goldfinger          2006        Horror
# 2     Adaptation Holes          2006   Documentary
# 3     Affair Prejudice          2006        Horror
# 4          African Egg          2006        Family
# ..                 ...           ...           ...
# 995     Young Language          2006   Documentary
# 996         Youth Kick          2006         Music
# 997       Zhivago Core          2006        Horror
# 998  Zoolander Fiction          2006      Children
# 999          Zorro Ark          2006        Comedy
#
# [1000 rows x 3 columns]

# %% [markdown]
# ``` mysql
# SELECT title AS film_name, release_year, name AS category_name, CONCAT(first_name, ' ', last_name) AS actor
# FROM film
# INNER JOIN (
#     SELECT name, film_id
#     FROM category
#     INNER JOIN film_category
#     USING(category_id)) AS subquery_one
# USING(film_id)
# INNER JOIN (
#     SELECT first_name, last_name, film_id
#     FROM actor
#     INNER JOIN film_actor
#     USING(actor_id)) AS subquery_two
# USING(film_id)
# WHERE name = 'Sci-Fi';
# ```

# %%
stmt = """SELECT title AS film_name, release_year, name AS category_name, CONCAT(first_name, ' ', last_name) AS actor 
FROM film 
INNER JOIN (
    SELECT name, film_id 
    FROM category 
    INNER JOIN film_category 
    USING(category_id)) AS subquery_one 
USING(film_id) 
INNER JOIN (
    SELECT first_name, last_name, film_id 
    FROM actor 
    INNER JOIN film_actor 
    USING(actor_id)) AS subquery_two 
USING(film_id) 
WHERE name = 'Sci-Fi';"""

pd.read_sql(stmt, conn)
# Out:
#                 film_name  release_year category_name             actor
# 0          Annie Identity          2006        Sci-Fi        Adam Grant
# 1          Annie Identity          2006        Sci-Fi      Cate Mcqueen
# 2          Annie Identity          2006        Sci-Fi      Greta Keitel
# 3         Armageddon Lost          2006        Sci-Fi     Angela Hudson
# 4         Armageddon Lost          2006        Sci-Fi        James Pitt
# ..                    ...           ...           ...               ...
# 321  Wonderland Christmas          2006        Sci-Fi      Cuba Olivier
# 322  Wonderland Christmas          2006        Sci-Fi       Woody Jolie
# 323  Wonderland Christmas          2006        Sci-Fi     Chris Bridges
# 324  Wonderland Christmas          2006        Sci-Fi     Harrison Bale
# 325  Wonderland Christmas          2006        Sci-Fi  Humphrey Garland
#
# [326 rows x 4 columns]

# %% [markdown]
# ``` mysql
# SELECT title AS film_name, release_year, name AS category_name, rating, COUNT(film_id) AS actor
# FROM film
# INNER JOIN (
#     SELECT name, film_id
#     FROM category
#     INNER JOIN film_category
#     USING(category_id)) AS subquery_one
# USING(film_id)
# INNER JOIN (
#     SELECT film_id
#     FROM actor
#     INNER JOIN film_actor
#     USING(actor_id)) AS subquery_two
# USING(film_id)
# WHERE name = 'Sci-Fi' AND (rating = 'R' OR rating = 'NC-17')
# GROUP BY title, release_year, name, rating
# ORDER BY actor DESC;
# ```

# %%
stmt = """SELECT title AS film_name, release_year, name AS category_name, rating, COUNT(film_id) AS n_actors 
FROM film 
INNER JOIN (
    SELECT name, film_id 
    FROM category 
    INNER JOIN film_category 
    USING(category_id)) AS subquery_one 
USING(film_id) 
INNER JOIN (
    SELECT film_id 
    FROM actor 
    INNER JOIN film_actor 
    USING(actor_id)) AS subquery_two 
USING(film_id) 
WHERE name = 'Sci-Fi' AND (rating = 'R' OR rating = 'NC-17') 
GROUP BY title, release_year, name, rating 
ORDER BY n_actors DESC;"""

pd.read_sql(stmt, conn)
# Out:
#                film_name  release_year category_name rating  n_actors
# 0              Random Go          2006        Sci-Fi  NC-17        13
# 1           Fiddler Lost          2006        Sci-Fi      R        11
# 2       Weekend Personal          2006        Sci-Fi      R        10
# 3     Soldiers Evolution          2006        Sci-Fi      R         9
# 4            Badman Dawn          2006        Sci-Fi      R         8
# 5         Express Lonely          2006        Sci-Fi      R         8
# 6        License Weekend          2006        Sci-Fi  NC-17         8
# 7      Connecticut Tramp          2006        Sci-Fi      R         7
# 8        Goldmine Tycoon          2006        Sci-Fi      R         7
# 9           None Spiking          2006        Sci-Fi  NC-17         6
# 10     Vacation Boondock          2006        Sci-Fi      R         6
# 11       Sun Confessions          2006        Sci-Fi      R         5
# 12          Panther Reds          2006        Sci-Fi  NC-17         5
# 13           Nemo Campus          2006        Sci-Fi  NC-17         5
# 14           Guys Falcon          2006        Sci-Fi      R         5
# 15         Hamlet Wisdom          2006        Sci-Fi      R         5
# 16       Crowds Telemark          2006        Sci-Fi      R         4
# 17  Cincinatti Whisperer          2006        Sci-Fi  NC-17         4
# 18   Disturbing Scarface          2006        Sci-Fi      R         4
# 19        Beverly Outlaw          2006        Sci-Fi      R         4
# 20         Hanky October          2006        Sci-Fi  NC-17         3
# 21       Raging Airplane          2006        Sci-Fi      R         3
# 22   Chariots Conspiracy          2006        Sci-Fi      R         2
# 23      Camelot Vacation          2006        Sci-Fi  NC-17         2
# 24       Hollow Jeopardy          2006        Sci-Fi  NC-17         2
# 25             Fish Opus          2006        Sci-Fi      R         2

# %% [markdown]
# Let's select the most rented movie of each category, counting the times the movie has been rented, and the amount of benefits that all rentals have produced.
#
# I realized that there are some rental_ids that do not have an amount value associated, so it would result in a row lost if we perform an inner join. We would use a left join instead, so the amount of n_rental are not disminished, and the sum of amount would be still the same.

# %% [markdown]
# ``` mysql
# SELECT film_title, category, n_rental, benefits_by_film, rank
# FROM (
#     SELECT title AS film_title, name AS category, n_rental, benefits_by_film, RANK() OVER(PARTITION BY name ORDER BY(n_rental) DESC) AS rank
#     FROM film
#     INNER JOIN (
#         SELECT name, film_id
#         FROM category
#         INNER JOIN film_category
#         USING(category_id)) AS subquery_one
#     USING(film_id)
#     INNER JOIN (
#         SELECT COUNT(rental_id) AS n_rental, film_id, SUM(benefits_by_rental_id) AS benefits_by_film
#         FROM (
#             SELECT inventory_id, rental_id, SUM(amount) AS benefits_by_rental_id
#             FROM rental
#             LEFT JOIN payment
#             USING(rental_id)
#             GROUP BY inventory_id, rental_id) AS subquery_one_two
#         INNER JOIN inventory
#         USING(inventory_id)
#         GROUP BY film_id
#         ORDER BY film_id) AS subquery_two
#     USING(film_id)
#     GROUP BY name, title, n_rental, benefits_by_film) AS subquery_general
# WHERE rank = 1
# ORDER BY category, benefits_by_film DESC;
# ```

# %% [markdown]
# Funciona, pero aquí no tengo 'category' así que el rank en el segundo inner join no se hace por category, si no por film_id

# %%
query = """SELECT film_title, category, n_rental, benefits_by_film, rank
FROM (
    SELECT title AS film_title, name AS category, n_rental, benefits_by_film, RANK() OVER(PARTITION BY name ORDER BY(n_rental) DESC) AS rank
    FROM film 
    INNER JOIN (
        SELECT name, film_id 
        FROM category 
        INNER JOIN film_category 
        USING(category_id)) AS subquery_one 
    USING(film_id)
    INNER JOIN (
        SELECT COUNT(rental_id) AS n_rental, film_id, SUM(benefits_by_rental_id) AS benefits_by_film
        FROM (
            SELECT inventory_id, rental_id, SUM(amount) AS benefits_by_rental_id
            FROM rental
            LEFT JOIN payment
            USING(rental_id)
            GROUP BY inventory_id, rental_id) AS subquery_one_two
        INNER JOIN inventory
        USING(inventory_id)
        GROUP BY film_id
        ORDER BY film_id) AS subquery_two 
    USING(film_id)
    GROUP BY name, title, n_rental, benefits_by_film) AS subquery_general
WHERE rank = 1
ORDER BY category, benefits_by_film DESC;"""

pd.read_sql(query, conn)
# Out:
#              film_title     category  n_rental  benefits_by_film  rank
# 0       Suspects Quills       Action        30            118.73     1
# 1   Rugrats Shakespeare       Action        30             67.72     1
# 2        Juggler Hardly    Animation        32             86.71     1
# 3          Robbers Joon     Children        31             85.74     1
# 4        Timberland Sky     Classics        31            102.74     1
# 5             Zorro Ark       Comedy        31            199.72     1
# 6             Wife Turn  Documentary        31            198.73     1
# 7          Hobbit Alien        Drama        31             68.74     1
# 8         Apache Divine       Family        31            160.72     1
# 9          Network Peak       Family        31            116.73     1
# 10      Rush Goodfellas       Family        31             81.72     1
# 11     Rocketeer Mother      Foreign        33             97.72     1
# 12       Forward Temple        Games        32            102.74     1
# 13       Grit Clockwork        Games        32             97.72     1
# 14         Pulp Beverly       Horror        30            121.74     1
# 15        Scalawag Duck        Music        32            157.71     1
# 16  Ridgemont Submarine          New        32            110.72     1
# 17    Goodfellas Salute       Sci-Fi        31            164.75     1
# 18  Gleaming Jawbreaker       Sports        29            125.72     1
# 19    Talented Homicide       Sports        29             34.76     1
# 20   Bucket Brotherhood       Travel        34            150.72     1

# %%
#%load_ext sql

# connect (en proceso)
#%sql postgresql+psycopg2://postgres:#hd!Prmr1984cn@localhost/DVDrental

#%sql SELECT first_name FROM actor;

# category_id 1 = action
#%%sql SELECT title AS film_title FROM film INNER JOIN film_category USING(film_id) WHERE category_id=1;

# %%
# close cursor
cur.close()

# %%
# close connection
conn.close()
